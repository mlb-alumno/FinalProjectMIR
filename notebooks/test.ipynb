# %%
import jams
import os
import pandas as pd
import re

# %%
notes_to_scale_degrees = {
    "C": "1",
    "C#": "#1",
    "Db": "b2",
    "D": "2",
    "D#": "#2",
    "Eb": "b3",
    "E": "3",
    "F": "4",
    "F#": "#4",
    "Gb": "b5",
    "G": "5",
    "G#": "#5",
    "Ab": "b6",
    "A": "6",
    "A#": "#6",
    "Bb": "b7",
    "B": "7",
}


def convert_chord_format(chord_str):
    """Convert chord to JAMS-compatible format."""
    if chord_str in ["N", "X"]:
        return chord_str

    # Regex for diminished (dim) and diminished 7th (dim7) chords
    dim_pattern = r"([A-Ga-g#]+):\((bb3|b3),\s*(b5)\)"
    dim7_pattern = r"([A-Ga-g#]+):\((bb3|b3),\s*(b5),\s*(bb7)\)"
    maj7_pattern = r"([A-Ga-g#]+):\((3),\s*(b5),\s*(b7)\)"

    # Check if the chord matches the diminished pattern (bb3, b5)
    if re.match(dim_pattern, chord_str):
        root = re.match(dim_pattern, chord_str).group(1)
        return f"{root}:dim"

    # Check if the chord matches the diminished 7th pattern (bb3, b5, bb7)
    elif re.match(dim7_pattern, chord_str):
        root = re.match(dim7_pattern, chord_str).group(1)
        return f"{root}:dim7"

    # Check if the chord matches the major 7th pattern (3, b5, b7)
    elif re.match(maj7_pattern, chord_str):
        root = re.match(maj7_pattern, chord_str).group(1)
        return f"{root}:maj7"

    # Handle inversions (chords with slash notation)
    if "/" in chord_str:
        return chord_str.split("/")[0]

    if ":(" in chord_str:
        chord_str = chord_str.split(":")[0]

    return chord_str

# %%
def csv_to_jams(csv_file_path, jams_file_path):
    """
    Converts a CSV file to a JAMS file, keeping only the shorthand column.

    Parameters:
        csv_file_path (str): Path to the input CSV file.
        jams_file_path (str): Path to save the output JAMS file.
    """

    # Load the CSV file into a DataFrame
    df = pd.read_csv(csv_file_path, delimiter=";")

    # Create a new JAMS object
    jam = jams.JAMS()

    # Set the file_metadata duration to 0
    jam.file_metadata.duration = 0

    # Create a new annotation for chords
    chord_annotation = jams.Annotation(namespace="chord")

    # Iterate through the rows of the DataFrame
    for _, row in df.iterrows():
        chord_annotation.append(
            time=row["start"],
            duration=row["end"] - row["start"],
            value=convert_chord_format(row["shorthand"]),
            confidence=1.0,
        )

    # Add the annotation to the JAMS object
    jam.annotations.append(chord_annotation)

    # Save the JAMS file
    jam.save(jams_file_path)

# %%
dataset_path = "/Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord"

for file in os.listdir(dataset_path):
    if file.endswith(".csv"):
        print(f"Converting {file}...")
        csv_file_path = os.path.join(dataset_path, file)
        jams_file_path = os.path.join(
            dataset_path, file.replace(".csv", ".jams")
        )
        csv_to_jams(csv_file_path, jams_file_path)
        print(f"Converted {csv_file_path} to {jams_file_path}")
# Out:
# Converting Beethoven_Op053-01_VA81.csv...
# C:maj
# D:7/C
# G:maj/B
# Bb:maj
# C:7/Bb
# F:maj/A
# F:min/Ab
# G:7
# D:hdim7/Ab
# G:7
# D:hdim7/Ab
# G:7
# D:hdim7/Ab
# G:7
# C:min
# G:maj
# C:maj
# D:7/C
# G:maj/B
# D:min
# E:7/D
# A:min/C
# A#:(bb3, b5)/C
# B:7
# E:min/B
# B:7
# E:min/B
# B:7
# E:min/B
# B:7
# E:min/B
# B:maj
# E:min/B
# B:maj
# E:min/B
# B:maj
# E:min/B
# B:maj
# E:min/B
# B:maj
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# B:7/F#
# E:maj/G#
# F#:min7/A
# E:maj/B
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# E:maj/B
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# B:7/F#
# E:maj/G#
# F#:min7/A
# E:maj/B
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# E:maj/B
# B:7
# E:maj
# B:7
# E:maj/B
# B:7
# E:maj
# B:7/F#
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/D#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# E:7/G#
# A:maj
# F#:7/A#
# E:maj/B
# D#:dim7
# D#:hdim7
# B:7/D#
# E:maj
# E:7
# A:min/E
# E:7
# A:min
# F#:dim/A
# E:min/B
# B:7
# E:min
# E:7
# A:min/E
# E:7
# A:min
# F#:dim/A
# E:min/B
# B:7
# E:min
# E:min/G
# F#:dim/A
# E:min/B
# B:7
# C:maj
# C:maj/E
# D:min/F
# C:maj/G
# G:7
# C:maj
# D:7/C
# G:maj/B
# Bb:maj
# C:7/Bb
# F:maj/A
# F:min/Ab
# G:7
# D:hdim7/Ab
# G:7
# D:hdim7/Ab
# G:7
# D:hdim7/Ab
# G:7
# C:min
# G:maj
# C:maj
# D:7/C
# G:maj/B
# D:min
# E:7/D
# A:min/C
# A#:(bb3, b5)/C
# B:7
# E:min/B
# B:7
# E:min/B
# B:7
# E:min/B
# B:7
# E:min/B
# B:maj
# E:min/B
# B:maj
# E:min/B
# B:maj
# E:min/B
# B:maj
# E:min/B
# B:maj
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# B:7/F#
# E:maj/G#
# F#:min7/A
# E:maj/B
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# E:maj/B
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# B:7/F#
# E:maj/G#
# F#:min7/A
# E:maj/B
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# E:maj/B
# B:7
# E:maj
# B:7
# E:maj/B
# B:7
# E:maj
# B:7/F#
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/D#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# E:7/G#
# A:maj
# F#:7/A#
# E:maj/B
# D#:dim7
# D#:hdim7
# B:7/D#
# E:maj
# E:7
# A:min/E
# E:7
# A:min
# F#:dim/A
# E:min/B
# B:7
# E:min
# E:7
# A:min/E
# E:7
# A:min
# F#:dim/A
# E:min/B
# B:7
# E:min
# E:min/G
# F#:dim/A
# E:min/B
# B:7
# C:maj
# C:maj/E
# D:min/F
# C:maj/G
# G:7
# C:maj
# F:maj/A
# G:min/Bb
# F:maj/C
# C:7
# D:min
# F:maj/A
# G:min/Bb
# F:maj/C
# C:7
# F:maj
# G:7/F
# C:maj/E
# C:min/Eb
# D:maj
# D:7/F#
# G:min
# D:7/A
# G:min/Bb
# D:7/F#
# G:min
# D:7/A
# G:min/Bb
# G:7/B
# C:min
# G:7/D
# C:min/Eb
# G:7/B
# C:min
# G:7/D
# C:min/Eb
# C:7/E
# F:min
# Bb:min/F
# Gb:maj7/F
# Db:maj/F
# F:7/Eb
# Bb:min/Db
# Eb:7/Db
# Ab:maj/C
# Db:maj7/C
# Gb:maj/Bb
# C:7/Bb
# F:min/Ab
# C:7/G
# F:min
# C:maj/E
# G:7/D
# C:maj
# G:7/D
# C:maj/E
# B:dim7/F
# C:7/G
# F:maj
# C:7/G
# F:maj/A
# E:dim7/Bb
# F:7/C
# Bb:maj
# F:7/C
# Bb:maj/D
# A:dim7/Eb
# Bb:7/F
# Eb:min
# Eb:min/Bb
# F:7/C
# Bb:min/Db
# G:maj/D
# C:min/Eb
# Db:maj/F
# F#:dim7
# G:7
# C:min/G
# D:7/F#
# G:7
# C:min/G
# D:7/F#
# G:maj
# C:min
# G:maj
# F#:dim7/C
# G:maj
# F#:dim7/C
# G:maj
# F#:dim7/C
# G:maj
# G:7
# C:maj
# D:7/C
# G:maj/B
# Bb:maj
# C:7/Bb
# F:maj/A
# F:min/Ab
# G:7
# D:hdim7/Ab
# G:7
# D:hdim7/Ab
# G:7
# D:hdim7/Ab
# G:7
# C:min
# Ab:maj
# Db:maj
# Bb:maj
# Eb:maj
# F:min7
# B:dim7/Ab
# F#:dim7/A
# F#:dim7
# G:maj
# G:7
# C:maj
# D:7/C
# G:maj/B
# D:min
# E:7/D
# A:min/C
# F:maj
# D#:(bb3, b5, bb7)/F
# E:7
# A:min/E
# E:7
# A:min/E
# E:7
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min/E
# E:maj
# A:min/E
# E:maj
# A:min/E
# E:maj
# A:min/E
# E:maj
# E:7
# A:maj
# E:maj
# F#:min
# C#:7
# D:maj
# E:7/B
# A:maj/C#
# B:min7/D
# A:maj/E
# E:7
# A:min
# E:min
# F:maj
# C:maj
# D:min
# C:maj/G
# G:7
# C:maj
# G#:dim7
# A:min
# E:7
# F:maj
# G:7/D
# C:maj/E
# D:min7/F
# C:maj/G
# G:7
# C:maj
# G#:dim7
# A:min
# E:7
# F:maj
# C:maj/G
# G:7
# C:maj
# G:7
# C:maj/G
# G:7
# C:maj
# G:7/D
# C:maj/E
# G:7/F
# C:maj/E
# G:7/B
# C:maj
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# G:7/F
# C:maj/E
# G:7/F
# C:maj/E
# G:7/F
# C:maj/E
# G:7/F
# C:maj/E
# C:7/E
# F:maj
# D:7/F#
# C:maj/G
# B:dim7
# B:hdim7
# G:7/B
# C:maj
# C:7
# F:min/C
# C:7
# F:min
# Db:maj/F
# C:min/G
# G:7
# C:7
# F:maj/C
# C:7
# F:maj
# D:min/F
# C:maj/G
# G:7
# C:maj
# C:maj/E
# D:min/F
# C:maj/G
# G:7
# C:maj
# F:maj/A
# G:min/Bb
# F:maj/C
# C:7
# F:min
# F:min/Ab
# G:dim/Bb
# F:min/C
# C:7
# Db:maj
# Eb:7/Db
# Ab:maj/C
# F:7/C
# Bb:min/Db
# B:dim/D
# C:min/Eb
# D:dim/F
# E:dim/G
# F:min/Ab
# F#:dim7/A
# F#:(bb3, b5, bb7)/Ab
# G:maj
# G#:dim7/D
# G:maj/B
# A:7/C#
# D:min
# F:maj/A
# G:7/B
# C:maj
# A:min/C
# D:min
# B:dim/D
# C#:dim
# D:min
# E:min
# F:maj
# G:maj
# A:min
# B:dim
# C:maj/E
# F:maj
# C:maj/G
# G:7
# C:maj
# G#:dim7
# A:min
# E:maj
# F:maj
# G:7/D
# C:maj/E
# D:min7/F
# C:maj/G
# G:7
# C:maj
# G#:dim7
# A:min
# E:7
# F:maj
# C:maj/G
# G:7
# C:maj/G
# G:7
# C:maj/G
# G:7
# C:maj
# D:7/C
# G:maj/B
# C:7/Bb
# F:maj/A
# F:min/Ab
# G:7
# C:maj
# G:maj
# C:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op053-01_VA81.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op053-01_VA81.jams
# Converting Beethoven_Op010No2-01_FJ62.csv...
# F:maj
# C:7/E
# F:maj
# C:7/G
# F:maj/A
# C:7/E
# F:maj/C
# F:7/Eb
# Bb:maj/D
# C:7/E
# F:maj
# G:min/Bb
# F:maj/C
# C:7
# F:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# G:maj
# C:maj
# G:7
# C:maj
# A:min
# D:7
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# D:7/F#
# G:maj
# D:7/F#
# G:maj
# G:7/F
# C:maj
# G:7/F
# C:maj
# D:min/F
# G:maj
# C:maj
# C:min/Eb
# D:dim/F
# G:maj/B
# C:min
# D:dim/F
# G:maj/B
# C:min
# D:dim/F
# G:7
# Ab:maj
# F#:dim7
# G:7/F
# C:maj
# G:7/D
# C:maj
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# D:min/F
# G:7
# C:maj
# F:maj
# D:7/F#
# C:maj/G
# G:maj
# C:maj
# F:maj
# D:7/F#
# C:maj/G
# G:maj
# C:maj
# F#:dim7/C
# G:maj
# C:maj
# F:maj
# C:7/E
# F:maj
# C:7/G
# F:maj/A
# C:7/E
# F:maj/C
# F:7/Eb
# Bb:maj/D
# C:7/E
# F:maj
# G:min/Bb
# F:maj/C
# C:7
# F:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# G:maj
# C:maj
# G:7
# C:maj
# A:min
# D:7
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# D:7/F#
# G:maj
# D:7/F#
# G:maj
# G:7/F
# C:maj
# G:7/F
# C:maj
# D:min/F
# G:maj
# C:maj
# C:min/Eb
# D:dim/F
# G:maj/B
# C:min
# D:dim/F
# G:maj/B
# C:min
# D:dim/F
# G:7
# Ab:maj
# F#:dim7
# G:7/F
# C:maj
# G:7/D
# C:maj
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# D:min/F
# G:7
# C:maj
# F:maj
# D:7/F#
# C:maj/G
# G:maj
# C:maj
# F:maj
# D:7/F#
# C:maj/G
# G:maj
# C:maj
# F#:dim7/C
# G:maj
# C:maj
# A:maj
# D:min
# A:maj
# D:min
# A:maj
# E:maj
# A:maj
# D:min
# A:maj
# D:min
# A:maj
# E:maj
# A:maj
# D:min
# A:7/E
# D:min/F
# A:7/C#
# D:min
# F#:dim/C
# G:min/Bb
# F#:dim
# G:min
# D:7/A
# G:min/Bb
# D:7/F#
# G:min
# F#:dim/C
# G:min/Bb
# F#:dim
# G:min
# E:dim/Bb
# F:7
# Bb:maj
# F:7/C
# Bb:maj/D
# F:7/A
# Bb:maj
# F:7
# Bb:min
# F:7
# Bb:min
# C:7
# F:min
# Db:maj
# F:min/C
# B:dim7
# G#:(bb3, b5, bb7)/Bb
# D:min/A
# A:maj
# D:maj
# A:7/C#
# D:maj
# A:7/E
# D:maj/F#
# G:maj
# D:7/A
# G:maj/B
# A:7/C#
# D:maj
# E:min/G
# D:maj/A
# A:7
# D:maj
# G:min
# C:7
# F:maj
# C:7/G
# F:maj/A
# G:min7/Bb
# F:maj/C
# F:7/Eb
# Bb:maj/D
# C:7/E
# F:maj
# G:min/Bb
# F:maj/C
# C:7
# F:maj
# C:7
# F:maj
# F:min/C
# F:min
# Eb:maj
# Eb:7/Bb
# Ab:maj
# F:7/Eb
# Bb:maj/D
# B:(bb3, b5)/Db
# C:maj
# G:7/B
# C:maj
# G:7/D
# C:maj
# G:7/B
# C:maj
# G:7/D
# C:maj
# G:7/D
# C:maj
# G:7/D
# C:maj
# C:7/Bb
# F:maj
# C:7/Bb
# F:maj
# G:min
# C:maj
# F:maj
# F:min
# G:dim/Bb
# C:maj/E
# F:min
# G:dim/Bb
# C:maj/E
# F:min
# G:dim/Bb
# C:7
# Db:maj
# B:dim7
# C:7/Bb
# F:maj
# C:7/G
# F:maj
# C:7/G
# F:maj/A
# C:7/G
# F:maj/A
# G:min/Bb
# C:7
# F:maj
# G:7/F
# F:maj/C
# C:7
# F:maj
# Bb:maj/D
# G:7/B
# F:maj/C
# C:maj
# F:maj
# Bb:maj/D
# G:7/B
# F:maj/C
# C:maj
# F:maj
# C:maj
# F:maj
# C:maj
# F:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op010No2-01_FJ62.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op010No2-01_FJ62.jams
# Converting Beethoven_Op014No1-01_VA81.csv...
# E:maj
# F#:min/A
# B:7/F#
# E:maj
# E:maj/B
# B:7
# E:maj/B
# B:7
# E:maj
# A:maj
# E:maj/B
# B:7
# E:maj
# A:maj
# E:maj/B
# B:7
# E:maj
# F#:min/A
# F#:maj/A#
# E:maj
# A:min/C
# F#:7/E
# E#:dim7
# F#:maj
# E#:dim7/B
# F#:maj
# E#:dim7/D
# F#:maj
# E#:dim7/B
# F#:maj
# E#:dim7/B
# F#:maj
# F#:maj
# B:maj
# G#:7/B#
# C#:min
# F#:maj/A#
# F#:7/A#
# B:maj
# B#:dim
# G#:maj
# G#:7
# C#:min
# F#:maj/A#
# F#:maj
# F#:7
# B:maj
# B:maj/D#
# F#:7/E
# B:maj/D#
# F#:7/E
# B:maj/D#
# B#:dim7/D#
# C#:min/E
# F#:7
# B:maj
# B:maj/D#
# F#:7/E
# B:maj/D#
# F#:7/E
# B:maj/D#
# B#:dim7/D#
# C#:min/E
# F#:7
# B:maj
# E:min/B
# F#:7
# B:maj
# E:maj/B
# F#:7
# B:maj
# E:min/B
# F#:7
# B:maj
# E:maj/B
# F#:7
# B:maj
# F#:7/C#
# B:maj/D#
# C#:min/E
# B:maj/F#
# F#:maj
# B:maj/D#
# F#:maj/C#
# B:maj
# C#:min/E
# B:maj/F#
# F#:maj
# B:maj/D#
# F#:maj/C#
# B:maj
# C#:min/E
# F#:7
# B:maj
# E:maj
# B:maj/D#
# E:maj/G#
# B:maj/F#
# F#:7/E
# B:maj/D#
# B:7
# E:maj
# F#:min/A
# B:7/F#
# E:maj
# E:maj/B
# B:7
# E:maj/B
# B:7
# E:maj
# A:maj
# E:maj/B
# B:7
# E:maj
# A:maj
# E:maj/B
# B:7
# E:maj
# F#:min/A
# F#:maj/A#
# E:maj
# A:min/C
# F#:7/E
# E#:dim7
# F#:maj
# E#:dim7/B
# F#:maj
# E#:dim7/D
# F#:maj
# E#:dim7/B
# F#:maj
# E#:dim7/B
# F#:maj
# F#:maj
# B:maj
# G#:7/B#
# C#:min
# F#:maj/A#
# F#:7/A#
# B:maj
# B#:dim
# G#:maj
# G#:7
# C#:min
# F#:maj/A#
# F#:maj
# F#:7
# B:maj
# B:maj/D#
# F#:7/E
# B:maj/D#
# F#:7/E
# B:maj/D#
# B#:dim7/D#
# C#:min/E
# F#:7
# B:maj
# B:maj/D#
# F#:7/E
# B:maj/D#
# F#:7/E
# B:maj/D#
# B#:dim7/D#
# C#:min/E
# F#:7
# B:maj
# E:min/B
# F#:7
# B:maj
# E:maj/B
# F#:7
# B:maj
# E:min/B
# F#:7
# B:maj
# E:maj/B
# F#:7
# B:maj
# F#:7/C#
# B:maj/D#
# C#:min/E
# B:maj/F#
# F#:maj
# B:maj/D#
# F#:maj/C#
# B:maj
# C#:min/E
# B:maj/F#
# F#:maj
# B:maj/D#
# F#:maj/C#
# B:maj
# C#:min/E
# F#:7
# B:maj
# E:maj
# B:maj/D#
# E:maj/G#
# B:maj/F#
# F#:7/E
# B:maj/D#
# B:7
# E:maj
# F:maj/A
# B:hdim7/D
# G#:dim7/D
# A:min/C
# D:min7
# A:min/E
# D:min7/F
# D:7/F#
# C:maj/G
# G:7
# C:maj
# E:min/B
# A#:dim7
# B:maj
# E:min
# B:maj
# E:min/G
# B:maj
# E:min
# B:maj
# A#:dim/C#
# B:maj
# E:min
# B:maj
# E:min/G
# B:maj
# E:min
# B:maj
# A#:dim/C#
# B:maj
# A:maj/C#
# E:maj/B
# B:7
# E:maj
# F#:min/A
# B:7/F#
# E:maj
# E:maj/B
# B:7
# E:maj/B
# B:7
# E:maj
# A:maj
# E:maj/B
# B:7
# E:maj
# A:maj
# E:maj/B
# B:maj
# E:maj
# B:7/F#
# A#:(bb3, b5, bb7)/C
# B:maj
# A#:dim7/E
# B:maj
# A#:dim7/G
# B:maj
# A#:dim7/E
# B:maj
# A#:dim7/G
# B:maj
# A#:dim7/E
# B:maj
# B:maj
# E:maj
# C#:7/E#
# F#:min
# B:maj/D#
# B:7/D#
# E:maj
# E#:dim
# C#:maj
# C#:7
# F#:min
# B:maj/D#
# B:maj
# B:7
# E:maj
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# E#:dim7/G#
# F#:min/A
# B:7
# E:maj
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# E#:dim7/G#
# F#:min/A
# B:7
# E:maj
# A:min/E
# B:7
# E:maj
# A:maj/E
# B:7
# E:maj
# A:min/E
# B:7
# E:maj
# A:maj/E
# B:7
# E:maj
# B:7/F#
# E:maj/G#
# F#:min/A
# E:maj/B
# B:maj
# E:maj/G#
# B:maj/F#
# E:maj
# F#:min/A
# E:maj/B
# B:maj
# E:maj/G#
# B:maj/F#
# E:maj
# F#:min/A
# B:7
# E:maj
# A:maj
# E:maj/G#
# A:maj/C#
# E:maj/B
# A:maj
# E:maj/G#
# D#:(bb3, b5)/F
# E:maj
# D#:dim/F#
# E:maj
# D#:(bb3, b5)/F
# E:maj
# D#:dim/F#
# E:maj
# B:7/D#
# E:maj
# B:7/A
# E:maj
# B:7/D#
# E:maj
# B:7/A
# E:maj
# B:7/A
# E:maj
# B:7/A
# E:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op014No1-01_VA81.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op014No1-01_VA81.jams
# Converting Beethoven_Op022-01_FG67.csv...
# Bb:maj
# Eb:maj
# F:7/Eb
# Bb:maj
# Bb:7
# Eb:maj
# F:7/C
# Bb:maj
# F:7
# Bb:maj
# F:7
# Bb:maj
# F:maj
# Bb:maj
# D:dim/F
# G:7
# Ab:maj
# D:maj/F#
# G:min
# C:maj/E
# F:maj
# G:7/F
# C:maj
# C:7
# F:maj
# G:7/F
# C:maj
# C:7
# F:maj
# G:7/F
# C:maj
# G:7/F
# C:maj
# G:7/F
# C:maj
# F:maj
# F:7/Eb
# D:7/A
# Eb:maj
# E:dim7
# F:maj
# G:min/Bb
# C:7
# F:maj
# Bb:maj
# G:min
# C:maj
# F:maj/A
# D:min
# Bb:maj
# E:dim
# C:maj/E
# Bb:maj/D
# A:7
# Bb:maj
# G:7/B
# F:maj/C
# C:maj
# F:maj
# Bb:maj
# G:min
# C:maj
# F:maj/A
# D:min
# Bb:maj
# E:dim
# C:maj/E
# Bb:maj/D
# A:7/C#
# D:min
# B:dim7
# E:dim7/Bb
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# Bb:maj/D
# G:min/Bb
# C:7
# F:maj
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# D:min/F
# D:7
# G:min
# C:maj
# F:maj
# G:dim/Bb
# C:7/G
# F:maj
# G:dim/Bb
# Gb:maj/Bb
# F:maj
# E:dim7/Bb
# F:maj
# Gb:maj/Bb
# F:maj
# C:7/Bb
# F:maj
# C:7
# F:maj
# C:7
# F:maj
# C:7
# F:maj
# Bb:maj
# Eb:maj
# F:7/Eb
# Bb:maj
# Bb:7
# Eb:maj
# F:7/C
# Bb:maj
# F:7
# Bb:maj
# F:7
# Bb:maj
# F:maj
# Bb:maj
# D:dim/F
# G:7
# Ab:maj
# D:maj/F#
# G:min
# C:maj/E
# F:maj
# G:7/F
# C:maj
# C:7
# F:maj
# G:7/F
# C:maj
# C:7
# F:maj
# G:7/F
# C:maj
# G:7/F
# C:maj
# G:7/F
# C:maj
# F:maj
# F:7/Eb
# D:7/A
# Eb:maj
# E:dim7
# F:maj
# G:min/Bb
# C:7
# F:maj
# Bb:maj
# G:min
# C:maj
# F:maj/A
# D:min
# Bb:maj
# E:dim
# C:maj/E
# Bb:maj/D
# A:7
# Bb:maj
# G:7/B
# F:maj/C
# C:maj
# F:maj
# Bb:maj
# G:min
# C:maj
# F:maj/A
# D:min
# Bb:maj
# E:dim
# C:maj/E
# Bb:maj/D
# A:7/C#
# D:min
# B:dim7
# E:dim7/Bb
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# Bb:maj/D
# G:min/Bb
# C:7
# F:maj
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# C:7/Bb
# F:maj/A
# C:7/E
# F:maj
# D:min/F
# D:7
# G:min
# C:maj
# F:maj
# G:dim/Bb
# C:7/G
# F:maj
# G:dim/Bb
# Gb:maj/Bb
# F:maj
# E:dim7/Bb
# F:maj
# Gb:maj/Bb
# F:maj
# C:7/Bb
# F:maj
# C:7
# F:maj
# C:7
# F:maj
# C:7
# F:maj
# F:maj
# C:min
# A:dim
# D:maj
# D:7
# G:min/D
# Eb:maj/G
# D:maj
# D:7
# G:min/D
# Eb:maj/G
# D:maj
# C#:dim7/G
# D:maj
# Eb:maj/G
# D:maj
# G:min
# F#:dim7/C
# G:maj
# C:min
# B:dim7/F
# C:maj
# F:min
# E:dim7/Bb
# F:min/Ab
# G:7
# C:min
# A:dim7/Gb
# F:7
# Bb:min
# G:dim7/Fb
# Eb:7
# C:7
# F:7
# Bb:maj
# Eb:maj
# F:7/Eb
# Bb:maj
# Bb:7
# Eb:maj
# F:7/C
# Bb:maj
# F:7
# Bb:maj
# F:7
# Bb:maj
# F:maj
# Bb:maj
# B:dim7
# C:min
# F:maj/A
# Bb:maj
# Eb:aug/G
# Ab:maj
# D:maj/F#
# G:min
# C:maj/E
# F:min
# Bb:maj/D
# Eb:maj
# A:dim/C
# Bb:maj/D
# E:hdim7
# F:maj
# F:7
# Bb:min
# C:7/Bb
# F:maj
# F:7
# Bb:min
# C:7/Bb
# F:maj
# C:7/Bb
# F:maj
# C:7/Bb
# F:maj
# Bb:maj
# Bb:7/Ab
# G:7/D
# Ab:maj
# A:dim7
# Bb:maj
# C:min/Eb
# F:7
# Bb:maj
# Eb:maj
# C:min
# F:maj
# Bb:maj/D
# G:min
# Eb:maj
# A:dim
# F:maj/A
# Eb:maj/G
# D:7
# Eb:maj
# C:7/E
# Bb:maj/F
# F:maj
# Bb:maj
# Eb:maj
# C:min
# F:maj
# Bb:maj/D
# G:min
# Eb:maj
# A:dim
# F:maj/A
# Eb:maj/G
# D:7/F#
# G:min
# E:dim7
# A:dim7/Eb
# F:7/Eb
# Bb:maj/D
# F:7/A
# Bb:maj
# F:7/Eb
# Bb:maj/D
# F:7/A
# Bb:maj
# F:7/Eb
# Bb:maj/D
# F:7/A
# Bb:maj
# F:7/Eb
# Bb:maj/D
# F:7/A
# Bb:maj
# Eb:maj/G
# C:min/Eb
# F:7
# Bb:maj
# F:7/Eb
# Bb:maj/D
# F:7/A
# Bb:maj
# F:7/Eb
# Bb:maj/D
# F:7/A
# Bb:maj
# F:7/Eb
# Bb:maj/D
# F:7/A
# Bb:maj
# G:min/Bb
# G:7
# C:min
# F:maj
# Bb:maj
# C:dim/Eb
# Cb:maj
# Bb:maj
# C:dim/Eb
# Cb:maj/Eb
# Bb:maj
# A:dim7/Eb
# Bb:maj
# Cb:maj/Eb
# Bb:maj
# F:7/Eb
# Bb:maj
# F:7
# Bb:maj
# F:7
# Bb:maj
# F:7
# Bb:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op022-01_FG67.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op022-01_FG67.jams
# Converting Beethoven_Op031No1-01_FG58.csv...
# G:maj
# E:min
# D:maj/A
# A:7
# D:maj
# F:maj
# D:min
# C:maj/G
# G:7
# C:maj
# A:min
# G:maj/D
# D:maj
# G:maj
# G:maj/D
# D:maj
# G:maj
# G:maj/D
# D:maj
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:maj
# G:maj
# D:maj
# G:maj
# E:min
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E:min/G
# E:min
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# B:maj
# F#:7
# F#:7/A#
# F#:7
# B:maj
# F#:7
# B:maj
# B:min
# F#:7/A#
# B:min
# E#:dim7/D
# A:7/C#
# D:maj
# B#:dim7/F#
# C#:7/E#
# F#:min
# D#:7
# E:min/G
# A:7
# D:maj/F#
# G:maj7
# C#:dim/E
# F#:7
# G:maj
# C#:dim/E
# F#:maj
# B:min
# A:maj
# D:maj
# C#:maj
# F#:min
# B:7/D#
# E:min
# A:7/C#
# D:maj
# G:maj7/B
# C#:dim
# F#:7/A#
# B:min
# C#:dim/E
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# G:maj
# E:min
# D:maj/A
# A:7
# D:maj
# F:maj
# D:min
# C:maj/G
# G:7
# C:maj
# A:min
# G:maj/D
# D:maj
# G:maj
# G:maj/D
# D:maj
# G:maj
# G:maj/D
# D:maj
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:maj
# G:maj
# D:maj
# G:maj
# E:min
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E:min/G
# E:min
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# B:maj
# F#:7
# F#:7/A#
# F#:7
# B:maj
# F#:7
# B:maj
# B:min
# F#:7/A#
# B:min
# E#:dim7/D
# A:7/C#
# D:maj
# B#:dim7/F#
# C#:7/E#
# F#:min
# D#:7
# E:min/G
# A:7
# D:maj/F#
# G:maj7
# C#:dim/E
# F#:7
# G:maj
# C#:dim/E
# F#:maj
# B:min
# A:maj
# D:maj
# C#:maj
# F#:min
# B:7/D#
# E:min
# A:7/C#
# D:maj
# G:maj7/B
# C#:dim
# F#:7/A#
# B:min
# C#:dim/E
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# G:maj
# G:7/F
# C:min/Eb
# G:7/D
# C:min
# C:7/Bb
# F:maj/A
# C:7/G
# F:maj
# F:7/Eb
# Bb:maj/D
# F:7/C
# Bb:maj
# F:7
# Bb:maj
# F:7
# Bb:maj
# F:min
# G:7/B
# C:min
# G:7
# C:min
# G:7
# C:min
# G:min
# A:7/C#
# D:min
# A:7
# D:min
# A:7
# D:7/F#
# G:min
# A:7/C#
# D:maj
# C#:(bb3, b5, bb7)/Eb
# D:maj
# C#:(bb3, b5, bb7)/Eb
# D:maj
# C#:(bb3, b5, bb7)/Eb
# D:maj
# C#:(bb3, b5, bb7)/Eb
# D:maj
# D:7
# F#:dim7
# D:7
# F#:dim7
# D:7
# F#:dim7
# D:7
# F#:dim7/Eb
# D:7
# G:maj
# E:min
# D:maj/A
# A:7
# D:maj
# A:min/C
# A:min
# G:maj/D
# D:maj
# G:maj
# A:min/C
# A:min
# B:maj
# A:min/C
# A#:(bb3, b5)/C
# B:maj
# A:min/C
# A#:(bb3, b5)/C
# B:maj
# A:min/C
# A#:(bb3, b5)/C
# B:maj
# E:maj
# B:7
# E:maj
# B:7
# E:maj
# E:min
# B:7/D#
# E:min
# C#:dim7/G
# D:7/F#
# D:7/C
# G:maj
# D:7
# D:7/F#
# D:7
# G:maj
# D:7
# G:maj
# D:7/F#
# G:maj
# E#:dim7/B
# F#:7/A#
# B:min
# G#:dim7/D
# A:7/C#
# D:min
# G:7
# C:maj/E
# F#:7
# B:min/D
# E:7
# A:min/C
# D:7
# E:min
# A:min/C
# D:maj
# G:maj
# F#:maj
# B:min
# A:maj
# D:min
# G:7/B
# C:maj
# F#:7/A#
# B:min
# E:7/G#
# A:min
# D:7/F#
# G:maj
# A:min/C
# D:7
# G:maj
# D:7
# G:min
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:maj
# G:maj
# D:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op031No1-01_FG58.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op031No1-01_FG58.jams
# Converting Beethoven_Op090-01_DB84.csv...
# E:min
# D:maj
# D:7/C
# G:maj
# F#:maj
# F#:7/E
# B:min
# G:maj/B
# A:min
# D:7
# G:maj
# E:min
# C:maj
# B:maj
# E:min/G
# F#:hdim7/A
# F#:7/A#
# B:7
# C:maj
# E:min/G
# E:maj/G#
# F#:hdim7/A
# F#:7/A#
# B:7
# E:min
# G:7
# G:7/B
# C:maj
# E:7
# E:7/G#
# A:min
# Bb:maj
# E:dim
# A#:dim7
# F#:7/A#
# B:min
# B:min/D
# B:7/D#
# C:maj/E
# D#:dim/F#
# D#:dim7/F#
# E:min/G
# E:7/G#
# C#:7/G#
# C#:7
# F#:7
# B:min
# E:min7
# B:min/F#
# F#:7
# B:min
# E:min7
# B:min/F#
# F#:7
# B:min
# E:min
# C:maj/E
# F#:7
# B:min
# E:min
# C:maj/E
# F#:7
# B:min
# F#:7
# B:min
# B:7/F#
# E:min
# G#:dim7/D
# A:min/C
# A:min
# B:dim7/Ab
# Bb:7/Ab
# Eb:maj/G
# A:dim7/Gb
# A:dim7/Eb
# A:dim7/C
# A:dim
# F#:dim
# F#:dim7/Eb
# D:7
# G:7
# C:maj
# D:min
# G:7
# C:maj
# C:7/Bb
# F:maj/A
# D:maj/F#
# G:min
# C:7
# F:maj
# D:min/F
# A:7/C#
# E:7/G#
# A:min
# E:7/B
# A:min/C
# B:7/D#
# A:min/E
# B:7/F#
# E:min/G
# F#:hdim7/A
# A#:dim7
# E:min/B
# E:min
# D:maj
# D:7/C
# G:maj
# F#:maj
# F#:7/E
# B:min
# G:maj/B
# A:min
# D:7
# G:maj
# E:min
# C:maj
# B:maj
# E:min/G
# F#:hdim7/A
# F#:7/A#
# B:7
# C:maj
# E:min/G
# E:maj/G#
# F#:hdim7/A
# F#:7/A#
# B:7
# E:min
# C:maj/G
# G:7/B
# C:maj
# E:7
# E:7/G#
# A:min
# F:maj
# D#:(bb3, b5, bb7)/F
# D#:dim7/F#
# B:7/F#
# E:min/G
# E:maj/G#
# E:7/G#
# F:maj/A
# G#:dim/B
# E:7/B
# A:min
# A#:dim7/C#
# F#:7
# B:7
# E:min
# A:min7
# E:min/B
# B:7
# E:min
# A:min7
# E:min/B
# B:7
# E:min
# A:min
# F:maj/A
# B:7
# E:min
# A:min
# F:maj/A
# B:7
# E:min
# B:7
# E:min
# B:7
# E:min
# B:7
# E:min
# B:7
# E:min
# D:maj
# D:7/C
# G:maj
# D#:dim7
# E:min/G
# F#:hdim7/A
# F#:7/A#
# B:7
# C:maj
# E:min/G
# E:maj/G#
# F#:hdim7/A
# F#:7/A#
# B:7
# E:min
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op090-01_DB84.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op090-01_DB84.jams
# Converting Beethoven_Op054-01_MB97.csv...
# C:maj
# F:maj
# G:min7
# C:maj
# F:maj/A
# Bb:maj
# F:maj/C
# C:7
# F:maj
# C:maj
# F:maj
# G:min7
# C:maj
# F:maj/A
# Bb:maj
# F:maj/C
# C:7
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# G:min
# C:maj/E
# Bb:maj/D
# E:dim
# A:maj/C#
# G:min/Bb
# C:7
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# G:min
# C:maj/E
# Bb:maj/D
# E:dim
# A:maj/C#
# G:min/Bb
# C:7
# F:maj
# F:maj/A
# G:min
# F:maj/A
# G:min/Bb
# F:maj
# E:dim/G
# D:min
# C#:dim/E
# Bb:maj
# B:hdim7
# C:maj
# F:maj/A
# G:min
# A:min/C
# F:maj/A
# G:min/Bb
# F:maj/A
# A:7/G
# D:min/F
# G:7/F
# C:maj/E
# A:7/G
# D:min/F
# G:7/F
# C:maj/E
# C:maj/E
# G:7/F
# C:maj
# G:7/F
# C:maj
# G:7
# C:maj
# Ab:maj/C
# Bb:min
# Ab:maj/C
# Bb:min/Db
# Ab:maj
# G:dim/Bb
# F:min
# Eb:maj/G
# Db:maj
# D:hdim7
# Eb:maj
# Ab:maj/C
# Bb:min
# C:min/Eb
# Ab:maj/C
# Bb:min/Db
# Ab:maj/C
# C:7/Bb
# F:min/Ab
# Ab:7/Gb
# Db:maj/F
# F:7/Eb
# Bb:min/Db
# Eb:7/Db
# Ab:maj/C
# F:7/Eb
# Bb:min/Db
# Eb:7/Db
# Ab:maj/C
# Eb:7/Db
# Ab:maj/C
# Eb:7/G
# Ab:maj
# Eb:7/Db
# Ab:maj
# Eb:7/Db
# Ab:maj
# Eb:7
# Ab:maj
# F:min
# C:maj
# F:min
# Db:maj
# Ab:maj
# Db:maj
# Bb:min/Db
# B:(bb3, b5)/Db
# C:maj
# F:maj
# G:min7
# C:maj
# F:maj/A
# Bb:maj
# F:maj/C
# C:7
# F:maj
# C:maj
# F:maj
# G:min7
# C:maj
# F:maj/A
# Bb:maj
# F:maj/C
# C:7
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# G:min
# C:maj/E
# Bb:maj/D
# E:dim
# A:maj/C#
# G:min/Bb
# C:7
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# G:min
# C:maj/E
# Bb:maj/D
# E:dim
# A:maj/C#
# G:min/Bb
# C:7
# F:maj
# F:maj/A
# G:min
# F:maj/A
# G:min/Bb
# F:maj
# E:dim/G
# D:min
# C#:dim/E
# Bb:maj
# B:hdim7
# C:maj
# C:7
# C:7/Bb
# C:maj
# F:maj/A
# Bb:maj
# C:maj
# F:maj/C
# Bb:min
# F:maj/C
# C:7
# F:maj
# C:maj
# F:maj/A
# Bb:maj
# C:maj
# F:maj/C
# Bb:min
# F:maj/C
# C:7
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# G:min
# C:maj/E
# Bb:maj/D
# E:dim
# A:maj/C#
# G:min/Bb
# C:7
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# G:min
# C:maj/E
# Bb:maj/D
# E:dim
# A:maj/C#
# G:min/Bb
# C:7/Bb
# F:maj/A
# Bb:maj
# C:7/Bb
# F:maj/A
# D:7/F#
# G:min
# C:7/E
# F:maj
# F:maj/A
# G:min/Bb
# C:7
# F:maj
# C:7/Bb
# F:maj
# C:7
# F:maj
# C:7/Bb
# F:maj
# C:7
# F:maj
# E:dim7/G
# C:7/E
# F:maj
# C:maj
# F:maj
# C:maj
# F:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op054-01_MB97.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op054-01_MB97.jams
# Converting Beethoven_Op031No1-01_WK64.csv...
# G:maj
# E:min
# D:maj/A
# A:7
# D:maj
# F:maj
# D:min
# C:maj/G
# G:7
# C:maj
# A:min
# G:maj/D
# D:maj
# G:maj
# G:maj/D
# D:maj
# G:maj
# G:maj/D
# D:maj
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:maj
# G:maj
# D:maj
# G:maj
# E:min
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E:min/G
# E:min
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# B:maj
# F#:7
# F#:7/A#
# F#:7
# B:maj
# F#:7
# B:maj
# B:min
# F#:7/A#
# B:min
# E#:dim7/D
# A:7/C#
# D:maj
# B#:dim7/F#
# C#:7/E#
# F#:min
# D#:7
# E:min/G
# A:7
# D:maj/F#
# G:maj7
# C#:dim/E
# F#:7
# G:maj
# C#:dim/E
# F#:maj
# B:min
# A:maj
# D:maj
# C#:maj
# F#:min
# B:7/D#
# E:min
# A:7/C#
# D:maj
# G:maj7/B
# C#:dim
# F#:7/A#
# B:min
# C#:dim/E
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# G:maj
# E:min
# D:maj/A
# A:7
# D:maj
# F:maj
# D:min
# C:maj/G
# G:7
# C:maj
# A:min
# G:maj/D
# D:maj
# G:maj
# G:maj/D
# D:maj
# G:maj
# G:maj/D
# D:maj
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:maj
# G:maj
# D:maj
# G:maj
# E:min
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E:min/G
# E:min
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# B:maj
# F#:7
# F#:7/A#
# F#:7
# B:maj
# F#:7
# B:maj
# B:min
# F#:7/A#
# B:min
# E#:dim7/D
# A:7/C#
# D:maj
# B#:dim7/F#
# C#:7/E#
# F#:min
# D#:7
# E:min/G
# A:7
# D:maj/F#
# G:maj7
# C#:dim/E
# F#:7
# G:maj
# C#:dim/E
# F#:maj
# B:min
# A:maj
# D:maj
# C#:maj
# F#:min
# B:7/D#
# E:min
# A:7/C#
# D:maj
# G:maj7/B
# C#:dim
# F#:7/A#
# B:min
# C#:dim/E
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# F#:7
# B:min
# G:maj
# G:7/F
# C:min/Eb
# G:7/D
# C:min
# C:7/Bb
# F:maj/A
# C:7/G
# F:maj
# F:7/Eb
# Bb:maj/D
# F:7/C
# Bb:maj
# F:7
# Bb:maj
# F:7
# Bb:maj
# F:min
# G:7/B
# C:min
# G:7
# C:min
# G:7
# C:min
# G:min
# A:7/C#
# D:min
# A:7
# D:min
# A:7
# D:7/F#
# G:min
# A:7/C#
# D:maj
# C#:(bb3, b5, bb7)/Eb
# D:maj
# C#:(bb3, b5, bb7)/Eb
# D:maj
# C#:(bb3, b5, bb7)/Eb
# D:maj
# C#:(bb3, b5, bb7)/Eb
# D:maj
# D:7
# F#:dim7
# D:7
# F#:dim7
# D:7
# F#:dim7
# D:7
# F#:dim7/Eb
# D:7
# G:maj
# E:min
# D:maj/A
# A:7
# D:maj
# A:min/C
# A:min
# G:maj/D
# D:maj
# G:maj
# A:min/C
# A:min
# B:maj
# A:min/C
# A#:(bb3, b5)/C
# B:maj
# A:min/C
# A#:(bb3, b5)/C
# B:maj
# A:min/C
# A#:(bb3, b5)/C
# B:maj
# E:maj
# B:7
# E:maj
# B:7
# E:maj
# E:min
# B:7/D#
# E:min
# C#:dim7/G
# D:7/F#
# D:7/C
# G:maj
# D:7
# D:7/F#
# D:7
# G:maj
# D:7
# G:maj
# D:7/F#
# G:maj
# E#:dim7/B
# F#:7/A#
# B:min
# G#:dim7/D
# A:7/C#
# D:min
# G:7
# C:maj/E
# F#:7
# B:min/D
# E:7
# A:min/C
# D:7
# E:min
# A:min/C
# D:maj
# G:maj
# F#:maj
# B:min
# A:maj
# D:min
# G:7/B
# C:maj
# F#:7/A#
# B:min
# E:7/G#
# A:min
# D:7/F#
# G:maj
# A:min/C
# D:7
# G:maj
# D:7
# G:min
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:maj
# G:maj
# D:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op031No1-01_WK64.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op031No1-01_WK64.jams
# Converting Beethoven_Op111-01_MC22.csv...
# F#:dim7
# G:maj
# C:min
# G:maj/B
# B:dim7
# E:dim7/Bb
# F:min/Ab
# C:maj/E
# E:dim7
# Bb:min/F
# Eb:min7/Gb
# Eb:7/G
# Ab:maj
# A:dim7
# Eb:min/Bb
# A:(bb3, b5, bb7)/Cb
# A:dim7
# Db:maj
# D:dim7
# Ab:maj/Eb
# E:dim7
# Bb:min/F
# E:dim7
# F:min/Ab
# F#:(bb3, b5)/Ab
# G:7
# C:min/Eb
# F#:dim7/Eb
# G:7/D
# C:min
# F#:dim7
# G:7
# C:min/Eb
# F#:dim7/Eb
# G:7/D
# C:min
# F#:dim7
# G:maj
# C:min
# G:maj
# C:min
# G:maj/B
# C:min
# G:maj/B
# G:maj
# C:min
# G:maj
# C:min
# G:maj
# C:min/Eb
# D:dim/F
# E:dim/G
# F:min/Ab
# G:maj/B
# C:min
# B:dim7/D
# G:7/D
# G:7
# C:min
# G:7
# C:min
# G:7
# C:min
# G:7
# C:min
# C:min/Eb
# F:min
# F:min/Ab
# F#:dim7/A
# F#:dim7
# C:min/G
# G:7
# C:min
# G:7
# C:min
# F:min/C
# D:hdim7
# Bb:7/D
# Eb:maj
# Bb:7
# F:min
# G:dim
# C:7/E
# G:dim
# Ab:maj
# F:7
# Bb:min/Db
# Bb:min
# G:dim7
# Eb:7
# Ab:maj
# Eb:7
# Ab:maj/C
# A:dim7
# Bb:min
# Eb:min
# C:hdim7
# Db:maj
# D:dim7
# Eb:maj
# Ab:maj/Eb
# Eb:7
# Ab:maj/Eb
# Eb:7
# Eb:7
# Ab:maj/Eb
# Eb:7
# E:dim7
# F:min
# G:hdim7/Db
# Ab:maj/C
# D:dim7
# Eb:maj
# Ab:maj
# Eb:7/G
# Ab:7/C
# Db:maj/F
# Db:min/Fb
# Ab:maj/Eb
# Eb:7
# Ab:maj
# Eb:maj
# Ab:7/C
# Db:maj
# Db:min
# Ab:maj/Eb
# Eb:7/G
# Ab:maj/C
# Eb:7
# Ab:maj/C
# Eb:7
# Ab:maj
# Eb:maj
# Ab:maj
# Eb:maj
# Ab:maj
# Eb:maj
# C:min
# G:maj
# C:min
# G:maj/B
# C:min
# G:maj/B
# G:maj
# C:min
# G:maj
# C:min
# G:maj
# C:min/Eb
# D:dim/F
# E:dim/G
# F:min/Ab
# G:maj/B
# C:min
# B:dim7/D
# G:7/D
# G:7
# C:min
# G:7
# C:min
# G:7
# C:min
# G:7
# C:min
# C:min/Eb
# F:min
# F:min/Ab
# F#:dim7/A
# F#:dim7
# C:min/G
# G:7
# C:min
# G:7
# C:min
# F:min/C
# D:hdim7
# Bb:7/D
# Eb:maj
# Bb:7
# F:min
# G:dim
# C:7/E
# G:dim
# Ab:maj
# F:7
# Bb:min/Db
# Bb:min
# G:dim7
# Eb:7
# Ab:maj
# Eb:7
# Ab:maj/C
# A:dim7
# Bb:min
# Eb:min
# C:hdim7
# Db:maj
# D:dim7
# Eb:maj
# Ab:maj/Eb
# Eb:7
# Ab:maj/Eb
# Eb:7
# Eb:7
# Ab:maj/Eb
# Eb:7
# E:dim7
# F:min
# G:hdim7/Db
# Ab:maj/C
# D:dim7
# Eb:maj
# Ab:maj
# Eb:7/G
# Ab:7/C
# Db:maj/F
# Db:min/Fb
# Ab:maj/Eb
# Eb:7
# Ab:maj
# Eb:maj
# Ab:7/C
# Db:maj
# Db:min
# Ab:maj/Eb
# Eb:7/G
# Ab:maj/C
# Eb:7
# Ab:maj/C
# Eb:7
# Ab:maj
# Eb:maj
# Ab:maj
# Eb:maj
# Ab:maj
# G:min
# D:maj/F#
# G:min
# D:maj/F#
# F:min
# C:maj/E
# C:min/Eb
# G:min/D
# D:7
# G:maj
# C:min/G
# F#:dim7
# D:7
# G:maj
# Ab:maj
# B:dim7/D
# G:7/B
# C:maj
# Db:maj/F
# E:dim7/G
# C:7
# F:min
# C:7/E
# F:min
# C:7/E
# F:min
# G:maj/B
# B:dim7
# G:maj
# F#:dim7/A
# F#:dim7/Eb
# B:dim7/D
# B:dim7/Ab
# E:dim7/G
# E:dim7/Bb
# F#:dim7/A
# F#:dim7/Eb
# B:dim7/D
# C:min/G
# G:maj
# C:min
# G:maj/B
# G:maj
# C:min
# G:7
# C:min
# G:7
# C:min
# G:7/B
# C:min
# C:min/Eb
# F:min
# Db:maj/F
# C:maj/E
# C:7
# F:min
# E:dim7
# C:7
# F:min
# A:dim7
# G:hdim7
# Ab:maj/C
# A:dim7
# F:7
# Bb:min
# F:7
# Bb:min
# Eb:min/Gb
# C:hdim7
# Ab:7/C
# Db:maj
# Ab:7
# Db:maj
# Bb:7
# Eb:min
# C:7
# F:min
# D:7
# G:min
# G:7
# C:min
# G:7
# C:min/Eb
# C:7/E
# F:min
# F#:dim7
# G:7
# C:maj/G
# G:7
# C:maj/G
# G:7
# G:7
# C:maj/G
# G:7
# G#:dim7
# A:min
# G:7/F
# C:maj/E
# B:dim7/F
# E:dim7
# G:hdim7/Db
# E:dim7/Db
# B:(bb3, b5, bb7)/Db
# F:min/C
# C:7
# F:min/Ab
# C:7
# F:min
# F#:dim7
# G:maj
# G:7
# Ab:maj
# F:7/A
# Bb:maj
# G:7/B
# C:min
# B:dim7/D
# C:min/Eb
# C:7/E
# F:min
# B:dim7/F
# F#:dim7
# G:maj
# C:min
# G:7/B
# C:7/Bb
# F:maj/A
# F#:(bb3, b5, bb7)/Ab
# C:min/G
# G:7
# C:min
# G:maj
# C:7/E
# F:maj
# F:min
# C:min/G
# G:maj
# C:min
# G:7/B
# G:maj
# C:min
# G:min/Bb
# C:min
# G:maj
# C:min
# G:maj
# C:min
# F#:dim7/Eb
# B:dim7/D
# B:dim7/F
# E:dim7/Db
# E:dim7
# F:maj/C
# C:min
# F:min
# C:7/E
# F:min
# G:7/F
# C:maj
# F:min
# C:7/E
# F:min
# G:7/F
# C:maj
# F:min
# C:7/E
# F:min
# B:dim7/F
# C:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op111-01_MC22.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op111-01_MC22.jams
# Converting Beethoven_Op027No1-01_MC22.csv...
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# Eb:maj
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# B:dim7
# C:min
# G:maj
# Ab:maj7
# F:maj/A
# Bb:7
# Eb:maj
# Bb:7
# B:dim7
# C:min
# G:maj
# Ab:maj7
# F:maj/A
# Bb:7
# Eb:maj
# Eb:maj
# Bb:7/F
# Bb:7
# Eb:maj
# Eb:maj
# Bb:7/F
# Bb:7
# Eb:maj
# C:maj
# B:dim
# C:7/Bb
# F:min/Ab
# C:7/E
# F:min
# Bb:7
# Eb:maj/Bb
# Bb:7
# Eb:maj
# C:maj
# B:dim
# C:7/Bb
# F:min/Ab
# C:maj/E
# F:min
# Bb:7
# Eb:maj/Bb
# Bb:7
# Eb:maj
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# Eb:maj
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# B:dim7
# C:min
# G:maj
# Ab:maj7
# F:maj/A
# Bb:7
# Eb:maj
# Bb:7
# B:dim7
# C:min
# G:maj
# Ab:maj7
# F:maj/A
# Bb:7
# Eb:maj
# C:maj
# G:7/D
# G:maj
# G:7/B
# C:maj
# C:maj
# A:min7/C
# F:maj
# B:hdim7/D
# E:7/G#
# A:min
# D:7
# G:maj
# C:maj
# G:7/D
# G:maj
# G:7/B
# C:maj
# C:maj
# A:min7/C
# F:maj
# B:hdim7/D
# E:7/G#
# A:min
# D:7
# G:maj
# G:maj
# G:7
# C:maj/E
# A:min7/C
# F:maj
# B:dim
# C:maj
# D:min7
# G:7
# C:maj
# G:maj
# G:7
# C:min/Eb
# Ab:maj7/C
# F:min
# Bb:7/D
# Bb:7
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# Eb:maj
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# Bb:7/Ab
# Eb:maj/G
# Bb:7
# B:dim7
# C:min
# G:maj
# Ab:maj7
# F:maj/A
# Bb:7
# Eb:maj
# Bb:7/F
# Bb:7/D
# B:dim7/D
# Ab:maj/Eb
# G:maj/B
# C:min
# F:maj/A
# Bb:7
# Eb:maj
# G:dim
# Ab:maj/Eb
# D:dim
# Eb:maj
# D:dim
# Eb:maj
# D:dim
# Eb:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op027No1-01_MC22.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op027No1-01_MC22.jams
# Converting Beethoven_Op031No2-01_JJ90.csv...
# A:maj/C#
# A:7/C#
# D:min
# A:maj/E
# D:min/F
# A:7/C#
# D:min
# A:maj/E
# D:min/F
# D:7/F#
# G:min
# D:min/A
# G:min/Bb
# G#:(bb3, b5)/Bb
# G#:dim7/D
# A:maj
# C:maj/E
# C:7/E
# F:maj
# D:7/F#
# G:min
# Eb:maj/G
# C#:dim7/G
# G#:dim7
# D:min/A
# A:7
# D:min
# A:7/E
# D:min/F
# E:maj/G#
# F:maj/A
# G#:dim/B
# A:min/C
# D#:dim7
# E:7
# A:min/E
# E:7
# A:min/C
# Bb:maj/D
# A:min/C
# Bb:maj/D
# A:min/C
# Bb:maj/D
# B:maj/D#
# A:min/E
# A:maj/E
# D:min/F
# A:maj/C#
# D:min
# Bb:maj/D
# A:min/E
# E:maj
# A:min
# Bb:maj
# A:maj
# Bb:maj
# A:maj
# Bb:maj
# G:7
# C:maj
# E:7
# A:min
# B:hdim7/D
# E:maj
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min/C
# E:7
# A:min/E
# E:maj
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min/C
# E:7
# A:min/E
# E:maj
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min
# E:maj
# A:min
# E:maj
# A:min
# A:maj/C#
# A:7/C#
# D:min
# A:maj/E
# D:min/F
# A:7/C#
# D:min
# A:maj/E
# D:min/F
# D:7/F#
# G:min
# D:min/A
# G:min/Bb
# G#:(bb3, b5)/Bb
# G#:dim7/D
# A:maj
# C:maj/E
# C:7/E
# F:maj
# D:7/F#
# G:min
# Eb:maj/G
# C#:dim7/G
# G#:dim7
# D:min/A
# A:7
# D:min
# A:7/E
# D:min/F
# E:maj/G#
# F:maj/A
# G#:dim/B
# A:min/C
# D#:dim7
# E:7
# A:min/E
# E:7
# A:min/C
# Bb:maj/D
# A:min/C
# Bb:maj/D
# A:min/C
# Bb:maj/D
# B:maj/D#
# A:min/E
# A:maj/E
# D:min/F
# A:maj/C#
# D:min
# Bb:maj/D
# A:min/E
# E:maj
# A:min
# Bb:maj
# A:maj
# Bb:maj
# A:maj
# Bb:maj
# G:7
# C:maj
# E:7
# A:min
# B:hdim7/D
# E:maj
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min/C
# E:7
# A:min/E
# E:maj
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min/C
# E:7
# A:min/E
# E:maj
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min
# E:maj
# A:min
# E:maj
# A:min
# D:maj/F#
# B#:dim7
# F#:maj/C#
# F#:min
# C#:7/G#
# F#:min/A
# B:min
# G:maj/B
# C:maj
# A:maj/C#
# D:min
# G#:dim/B
# G#:(bb3, b5)/Bb
# A:maj
# B:hdim7/A
# A:maj
# B:hdim7/A
# A:maj
# B:hdim7/A
# A:maj
# A:maj/C#
# B:hdim7
# A:maj/C#
# B:hdim7
# A:maj/C#
# B:hdim7
# A:maj
# B:hdim7/A
# A:maj
# B:hdim7/A
# A:maj
# B:hdim7/A
# A:maj
# D:min/A
# A:maj
# Bb:maj/D
# A:maj
# C#:dim7
# A:maj/C#
# A:7/C#
# D:min
# A:maj/E
# D:min/F
# A:7/C#
# D:min
# A:maj/E
# D:min/F
# D:7/F#
# G:min
# D:min/A
# G:min/Bb
# G#:(bb3, b5)/Bb
# G#:dim7/D
# A:maj
# C:maj/E
# E:dim7
# F:min
# C#:maj/E#
# F#:min
# D:maj/F#
# G:min
# C#:dim7/G
# G#:dim7
# A:7
# D:min/A
# A:7
# D:min/F
# Eb:maj/G
# D:min/F
# Eb:maj/G
# D:min/F
# Eb:maj/G
# E:maj/G#
# D:min/A
# D:maj/A
# G:min/Bb
# D:maj/F#
# G:min
# Eb:maj/G
# D:min/A
# A:maj
# D:min
# Eb:maj
# D:maj
# Eb:maj
# D:maj
# Eb:maj
# C:7
# F:maj
# A:7
# D:min
# E:hdim7/G
# A:maj
# D:min/A
# A:7
# D:min/A
# A:maj
# D:min/F
# A:7
# D:min/A
# A:maj
# D:min/A
# A:7
# D:min/A
# A:maj
# D:min/F
# A:7
# D:min/A
# A:maj
# D:min/A
# A:7
# D:min/A
# A:maj
# D:min
# A:maj
# D:min
# A:maj
# D:min
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op031No2-01_JJ90.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op031No2-01_JJ90.jams
# Converting Beethoven_Op028-01_JJ90.csv...
# D:maj
# D:7
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:7
# G:maj
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:maj/F#
# E:min
# D:7/A
# G:maj/B
# D:7/A
# G:maj
# E:7/G#
# A:maj
# A:7
# D:maj
# A:7
# D:maj/F#
# E:min
# D:maj/A
# G:maj/B
# D:maj/A
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# D:maj/F#
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# B:min7/D
# A:maj/C#
# E:7/B
# A:maj
# F#:min7/A
# E:maj/G#
# B:7/F#
# E:maj
# B:min7/D
# A:maj/C#
# E:7/B
# A:maj
# F#:min7/A
# E:maj/G#
# B:7/F#
# E:maj
# B:7/F#
# E:maj
# B:7/F#
# E:maj
# C#:7
# F#:min
# C#:7
# F#:min
# F#:7
# B:min
# A:maj/C#
# E:7
# A:maj
# C#:maj
# F#:min
# C#:maj
# F#:min/A
# B:min/D
# B#:(bb3, b5)/D
# C#:maj
# B#:(bb3, b5)/D
# C#:maj
# B#:(bb3, b5)/D
# C#:maj
# B#:(bb3, b5)/D
# C#:maj
# A#:min7
# E#:dim7/B
# A#:min7
# E#:dim7/B
# A#:min7
# E#:dim7/B
# E:7/B
# A#:hdim7
# E:7/B
# A#:hdim7
# E:7/B
# A:maj
# E:7/B
# A:maj
# C#:7/G#
# F#:min
# C#:7/G#
# F#:min
# C#:7/G#
# F#:min
# A:7/E
# D:maj
# A:7/E
# D:maj
# A:7/E
# D:maj
# E:7/B
# A:maj/C#
# E:maj/G#
# A:maj
# D:maj/F#
# A:maj/C#
# D#:dim/F#
# A:maj/E
# E:7
# A:maj/C#
# B#:dim7
# A:maj/C#
# D:maj
# A:maj/C#
# E:7/B
# A:maj
# E:aug/G#
# A:maj
# E:7/B
# A:maj
# C#:7/G#
# F#:min
# C#:maj/E#
# F#:min
# C#:maj/E#
# F#:min
# F#:7/E
# B:min/D
# F#:maj/A#
# B:min/D
# B:7/A
# E:maj/G#
# B:maj/D#
# E:min
# E:7/D
# A:maj/C#
# B:7/F#
# A:maj/E
# E:7
# A:maj
# A:maj/C#
# E:7
# A:maj
# A:7/C#
# D:maj
# E:7
# A:maj
# A:maj/C#
# E:7
# A:maj
# A:7/C#
# D:maj
# E:7
# A:maj
# A:7/C#
# D:maj
# E:7
# A:maj
# E:7
# A:maj
# E:7
# A:maj
# A:7
# D:maj
# D:7
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:7
# G:maj
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:maj/F#
# E:min
# D:7/A
# G:maj/B
# D:7/A
# G:maj
# E:7/G#
# A:maj
# A:7
# D:maj
# A:7
# D:maj/F#
# E:min
# D:maj/A
# G:maj/B
# D:maj/A
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# D:maj/F#
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# B:min7/D
# A:maj/C#
# E:7/B
# A:maj
# F#:min7/A
# E:maj/G#
# B:7/F#
# E:maj
# B:min7/D
# A:maj/C#
# E:7/B
# A:maj
# F#:min7/A
# E:maj/G#
# B:7/F#
# E:maj
# B:7/F#
# E:maj
# B:7/F#
# E:maj
# C#:7
# F#:min
# C#:7
# F#:min
# F#:7
# B:min
# A:maj/C#
# E:7
# A:maj
# C#:maj
# F#:min
# C#:maj
# F#:min/A
# B:min/D
# B#:(bb3, b5)/D
# C#:maj
# B#:(bb3, b5)/D
# C#:maj
# B#:(bb3, b5)/D
# C#:maj
# B#:(bb3, b5)/D
# C#:maj
# A#:min7
# E#:dim7/B
# A#:min7
# E#:dim7/B
# A#:min7
# E#:dim7/B
# E:7/B
# A#:hdim7
# E:7/B
# A#:hdim7
# E:7/B
# A:maj
# E:7/B
# A:maj
# C#:7/G#
# F#:min
# C#:7/G#
# F#:min
# C#:7/G#
# F#:min
# A:7/E
# D:maj
# A:7/E
# D:maj
# A:7/E
# D:maj
# E:7/B
# A:maj/C#
# E:maj/G#
# A:maj
# D:maj/F#
# A:maj/C#
# D#:dim/F#
# A:maj/E
# E:7
# A:maj/C#
# B#:dim7
# A:maj/C#
# D:maj
# A:maj/C#
# E:7/B
# A:maj
# E:aug/G#
# A:maj
# E:7/B
# A:maj
# C#:7/G#
# F#:min
# C#:maj/E#
# F#:min
# C#:maj/E#
# F#:min
# F#:7/E
# B:min/D
# F#:maj/A#
# B:min/D
# B:7/A
# E:maj/G#
# B:maj/D#
# E:min
# E:7/D
# A:maj/C#
# B:7/F#
# A:maj/E
# E:7
# A:maj
# A:maj/C#
# E:7
# A:maj
# A:7/C#
# D:maj
# E:7
# A:maj
# A:maj/C#
# E:7
# A:maj
# A:7/C#
# D:maj
# E:7
# A:maj
# A:7/C#
# D:maj
# E:7
# A:maj
# E:7
# A:maj
# E:7
# A:maj
# A:7
# D:maj/F#
# D:7/F#
# G:maj
# G:7
# C:maj
# C:maj/E
# A:min7
# D:7/F#
# G:maj
# G:maj/B
# D:7
# G:maj
# D:7
# C:min
# C:min/Eb
# A:hdim7
# F#:dim7
# G:min
# D:7
# G:min
# A:maj/C#
# D:min
# A:7/C#
# D:min
# D:maj
# G:min
# D:7/F#
# G:min
# A:maj
# D:min
# A:7/C#
# D:min
# A:7/C#
# D:min
# A:7/C#
# D:min
# B:7/D#
# E:7/G#
# A:min
# E:7/G#
# A:min
# E:7/G#
# A:min
# D#:dim7/F#
# E:min
# B:7
# E:min
# A#:dim7/C#
# B:min
# F#:7
# B:min
# E#:(bb3, b5, bb7)/G
# F#:maj
# B:min/F#
# F#:7
# B:min/F#
# F#:maj
# B:min/F#
# F#:7
# B:min/F#
# F#:maj
# B:maj
# B:maj/D#
# F#:7
# B:maj
# B:min
# B:min/D
# F#:7
# B:min
# A:7
# D:maj
# D:7
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:7
# D:7/F#
# G:maj
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:maj/F#
# E:min7/G
# D:7/A
# G:maj/B
# D:7/A
# G:maj
# E:7/G#
# A:maj
# A:7
# D:maj
# A:7
# D:maj/F#
# E:min
# D:maj/A
# G:maj/B
# D:maj/A
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# D:maj/F#
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# D:maj/F#
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# B:min7/D
# A:maj/C#
# E:7/B
# A:maj
# E:min7/G
# D:maj/F#
# A:7/E
# D:maj
# B:min7/D
# A:maj/C#
# E:7/B
# A:maj
# E:min7/G
# D:maj/F#
# A:7/E
# D:maj
# E:7/B
# A:maj
# E:7/B
# A:maj
# E:7/B
# A:maj
# F#:7
# B:min
# F#:7
# B:min
# B:7
# E:min
# D:maj/F#
# A:7
# D:maj
# F#:maj
# B:min
# F#:maj
# B:min/D
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E#:(bb3, b5)/G
# F#:maj
# E#:(bb3, b5)/G
# F#:maj
# E#:(bb3, b5)/G
# F#:maj
# D#:min7
# A#:dim7/E
# D#:min7
# A#:dim7/E
# D#:min7
# A#:dim7/E
# A:7/E
# D#:hdim7
# A:7/E
# D#:hdim7
# A:7/E
# D:maj
# A:7/E
# D:maj
# F#:7/C#
# B:min
# F#:7/C#
# B:min
# F#:7/C#
# B:min
# D:7/A
# G:maj
# D:7/A
# G:maj
# D:7/A
# G:maj
# A:7/E
# D:maj/F#
# A:maj/C#
# D:maj
# G:maj/B
# D:maj/F#
# G#:dim/B
# D:maj/A
# A:7
# D:maj/F#
# E#:dim7
# D:maj/F#
# G:maj
# D:maj/F#
# A:7/E
# D:maj
# A:aug/C#
# D:maj
# A:7/E
# D:maj
# F#:7/C#
# B:min
# F#:maj/A#
# B:min
# F#:maj/A#
# B:min
# B:7/A
# E:min/G
# B:maj/D#
# E:min/G
# E:7/D
# A:maj/C#
# E:maj/G#
# A:min
# A:7/G
# D:maj/F#
# G#:dim/B
# D:maj/A
# A:7
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:7/F#
# G:maj
# A:7
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:7/F#
# G:maj
# A:7
# D:maj
# D:7/F#
# G:maj
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# D:7
# G:maj
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op028-01_JJ90.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op028-01_JJ90.jams
# Converting Beethoven_Op090-01_FJ62.csv...
# E:min
# D:maj
# D:7/C
# G:maj
# F#:maj
# F#:7/E
# B:min
# G:maj/B
# A:min
# D:7
# G:maj
# E:min
# C:maj
# B:maj
# E:min/G
# F#:hdim7/A
# F#:7/A#
# B:7
# C:maj
# E:min/G
# E:maj/G#
# F#:hdim7/A
# F#:7/A#
# B:7
# E:min
# G:7
# G:7/B
# C:maj
# E:7
# E:7/G#
# A:min
# Bb:maj
# E:dim
# A#:dim7
# F#:7/A#
# B:min
# B:min/D
# B:7/D#
# C:maj/E
# D#:dim/F#
# D#:dim7/F#
# E:min/G
# E:7/G#
# C#:7/G#
# C#:7
# F#:7
# B:min
# E:min7
# B:min/F#
# F#:7
# B:min
# E:min7
# B:min/F#
# F#:7
# B:min
# E:min
# C:maj/E
# F#:7
# B:min
# E:min
# C:maj/E
# F#:7
# B:min
# F#:7
# B:min
# B:7/F#
# E:min
# G#:dim7/D
# A:min/C
# A:min
# B:dim7/Ab
# Bb:7/Ab
# Eb:maj/G
# A:dim7/Gb
# A:dim7/Eb
# A:dim7/C
# A:dim
# F#:dim
# F#:dim7/Eb
# D:7
# G:7
# C:maj
# D:min
# G:7
# C:maj
# C:7/Bb
# F:maj/A
# D:maj/F#
# G:min
# C:7
# F:maj
# D:min/F
# A:7/C#
# E:7/G#
# A:min
# E:7/B
# A:min/C
# B:7/D#
# A:min/E
# B:7/F#
# E:min/G
# F#:hdim7/A
# A#:dim7
# E:min/B
# E:min
# D:maj
# D:7/C
# G:maj
# F#:maj
# F#:7/E
# B:min
# G:maj/B
# A:min
# D:7
# G:maj
# E:min
# C:maj
# B:maj
# E:min/G
# F#:hdim7/A
# F#:7/A#
# B:7
# C:maj
# E:min/G
# E:maj/G#
# F#:hdim7/A
# F#:7/A#
# B:7
# E:min
# C:maj/G
# G:7/B
# C:maj
# E:7
# E:7/G#
# A:min
# F:maj
# D#:(bb3, b5, bb7)/F
# D#:dim7/F#
# B:7/F#
# E:min/G
# E:maj/G#
# E:7/G#
# F:maj/A
# G#:dim/B
# E:7/B
# A:min
# A#:dim7/C#
# F#:7
# B:7
# E:min
# A:min7
# E:min/B
# B:7
# E:min
# A:min7
# E:min/B
# B:7
# E:min
# A:min
# F:maj/A
# B:7
# E:min
# A:min
# F:maj/A
# B:7
# E:min
# B:7
# E:min
# B:7
# E:min
# B:7
# E:min
# B:7
# E:min
# D:maj
# D:7/C
# G:maj
# D#:dim7
# E:min/G
# F#:hdim7/A
# F#:7/A#
# B:7
# C:maj
# E:min/G
# E:maj/G#
# F#:hdim7/A
# F#:7/A#
# B:7
# E:min
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op090-01_FJ62.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op090-01_FJ62.jams
# Converting Beethoven_Op049No2-01_MC22.csv...
# G:maj
# G:maj/B
# D:maj/A
# G:maj
# D:maj/F#
# D:maj
# G:maj
# G:7/F
# E:min7
# D:7/F#
# G:maj
# G:maj/B
# D:maj/A
# G:maj
# D:maj/F#
# D:maj
# G:maj
# G:7/F
# E:min7
# D:7/F#
# G:maj
# A:min/C
# G:maj/B
# C:maj
# D:maj
# G:maj
# A:min/C
# A:7/C#
# D:7
# G:maj/D
# D:7
# G:maj/D
# D:maj
# G:maj/D
# D:maj
# G:maj/D
# D:maj
# D:maj/F#
# A:7/G
# D:maj/F#
# A:maj/C#
# D:maj
# A:maj/C#
# A:maj
# A:7/G
# D:maj/F#
# A:maj/E
# D:maj
# A:7/C#
# D:maj
# E:min/G
# D:maj/F#
# E:min/G
# D:maj/F#
# E:min/G
# E:7/G#
# A:maj
# D:maj/F#
# A:7/G
# D:maj/F#
# A:maj/C#
# D:maj
# A:maj
# A:7/G
# D:maj/F#
# A:maj/E
# D:maj
# A:7/C#
# D:maj
# E:min/G
# D:maj/F#
# E:min/G
# D:maj/F#
# E:min/G
# A:maj
# D:maj
# A:7/E
# D:maj
# A:7/C#
# D:maj
# D:7
# G:maj
# D:maj/A
# A:7
# D:maj
# G:maj
# D:maj
# E:min/G
# D:maj/A
# A:maj
# D:maj
# G:maj
# D:maj
# E:min/G
# D:maj/A
# A:maj
# D:maj
# A:7/G
# D:maj
# A:7/G
# D:maj
# A:7/G
# D:maj
# A:7/G
# D:maj
# G:maj
# G:maj/B
# D:maj/A
# G:maj
# D:maj/F#
# D:maj
# G:maj
# G:7/F
# E:min7
# D:7/F#
# G:maj
# G:maj/B
# D:maj/A
# G:maj
# D:maj/F#
# D:maj
# G:maj
# G:7/F
# E:min7
# D:7/F#
# G:maj
# A:min/C
# G:maj/B
# C:maj
# D:maj
# G:maj
# A:min/C
# A:7/C#
# D:7
# G:maj/D
# D:7
# G:maj/D
# D:maj
# G:maj/D
# D:maj
# G:maj/D
# D:maj
# D:maj/F#
# A:7/G
# D:maj/F#
# A:maj/C#
# D:maj
# A:maj/C#
# A:maj
# A:7/G
# D:maj/F#
# A:maj/E
# D:maj
# A:7/C#
# D:maj
# E:min/G
# D:maj/F#
# E:min/G
# D:maj/F#
# E:min/G
# E:7/G#
# A:maj
# D:maj/F#
# A:7/G
# D:maj/F#
# A:maj/C#
# D:maj
# A:maj
# A:7/G
# D:maj/F#
# A:maj/E
# D:maj
# A:7/C#
# D:maj
# E:min/G
# D:maj/F#
# E:min/G
# D:maj/F#
# E:min/G
# A:maj
# D:maj
# A:7/E
# D:maj
# A:7/C#
# D:maj
# D:7
# G:maj
# D:maj/A
# A:7
# D:maj
# G:maj
# D:maj
# E:min/G
# D:maj/A
# A:maj
# D:maj
# G:maj
# D:maj
# E:min/G
# D:maj/A
# A:maj
# D:maj
# A:7/G
# D:maj
# A:7/G
# D:maj
# A:7/G
# D:maj
# A:7/G
# D:maj
# D:min
# A:min/C
# E:7/D
# A:min/C
# E:maj/G#
# A:min
# E:7/B
# A:min/C
# E:7/B
# A:min
# E:min/G
# B:7/A
# E:min/G
# B:maj/D#
# E:min
# A#:(bb3, b5, bb7)/C
# B:maj
# B:7
# E:min/B
# B:maj
# E:min/B
# B:maj
# B:7
# E:min/B
# B:maj
# E:min/B
# B:maj
# B:7
# E:min
# E:min7
# A:min
# A:min7
# D:maj
# D:7
# G:maj
# G:maj/B
# D:maj/A
# G:maj
# D:maj/F#
# D:maj
# G:maj
# G:7/F
# E:min7
# D:7/F#
# G:maj
# G:maj/B
# D:maj/A
# G:maj
# D:maj/F#
# D:maj
# G:maj
# G:7/F
# C:maj/E
# F:maj
# C:maj/G
# G:7
# C:maj
# G:7/D
# C:maj
# G:7/B
# C:maj
# E:7/B
# A:min/C
# A:7/C#
# D:7
# G:maj/D
# D:7
# G:maj/D
# D:maj
# G:maj/D
# D:maj
# G:maj/D
# D:maj
# G:maj/B
# D:7/C
# G:maj/B
# D:maj/F#
# G:maj
# D:maj/F#
# D:maj
# D:7/C
# G:maj/B
# D:maj/A
# G:maj
# D:7/F#
# G:maj
# A:min/C
# G:maj/B
# A:min/C
# G:maj/B
# A:min/C
# A:7/C#
# D:maj
# G:maj/B
# D:7/C
# G:maj/B
# D:maj/F#
# G:maj
# D:maj/F#
# D:maj
# D:7/C
# G:maj/B
# D:maj/A
# G:maj
# D:7/F#
# G:maj
# A:min/C
# G:maj/B
# A:min/C
# G:maj/B
# A:min/C
# G:maj/D
# D:maj
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# G:7/B
# G#:dim7/B
# A:min/C
# G:maj/D
# D:7
# G:maj
# C:maj
# G:maj
# A:min/C
# G:maj/D
# D:maj
# G:maj
# C:maj
# G:maj
# A:min/C
# G:maj/D
# D:maj
# G:maj
# D:7/C
# G:maj
# D:7/C
# G:maj
# D:7/C
# G:maj
# D:7/C
# G:maj
# D:7/C
# G:maj
# D:7/C
# G:maj
# D:7
# G:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op049No2-01_MC22.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op049No2-01_MC22.jams
# Converting Beethoven_Op010No2-01_DB84.csv...
# F:maj
# C:7/E
# F:maj
# C:7/G
# F:maj/A
# C:7/E
# F:maj/C
# F:7/Eb
# Bb:maj/D
# C:7/E
# F:maj
# G:min/Bb
# F:maj/C
# C:7
# F:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# G:maj
# C:maj
# G:7
# C:maj
# A:min
# D:7
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# D:7/F#
# G:maj
# D:7/F#
# G:maj
# G:7/F
# C:maj
# G:7/F
# C:maj
# D:min/F
# G:maj
# C:maj
# C:min/Eb
# D:dim/F
# G:maj/B
# C:min
# D:dim/F
# G:maj/B
# C:min
# D:dim/F
# G:7
# Ab:maj
# F#:dim7
# G:7/F
# C:maj
# G:7/D
# C:maj
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# D:min/F
# G:7
# C:maj
# F:maj
# D:7/F#
# C:maj/G
# G:maj
# C:maj
# F:maj
# D:7/F#
# C:maj/G
# G:maj
# C:maj
# F#:dim7/C
# G:maj
# C:maj
# F:maj
# C:7/E
# F:maj
# C:7/G
# F:maj/A
# C:7/E
# F:maj/C
# F:7/Eb
# Bb:maj/D
# C:7/E
# F:maj
# G:min/Bb
# F:maj/C
# C:7
# F:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# G:maj
# C:maj
# G:7
# C:maj
# A:min
# D:7
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# D:7/F#
# G:maj
# D:7/F#
# G:maj
# G:7/F
# C:maj
# G:7/F
# C:maj
# D:min/F
# G:maj
# C:maj
# C:min/Eb
# D:dim/F
# G:maj/B
# C:min
# D:dim/F
# G:maj/B
# C:min
# D:dim/F
# G:7
# Ab:maj
# F#:dim7
# G:7/F
# C:maj
# G:7/D
# C:maj
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# D:min/F
# G:7
# C:maj
# F:maj
# D:7/F#
# C:maj/G
# G:maj
# C:maj
# F:maj
# D:7/F#
# C:maj/G
# G:maj
# C:maj
# F#:dim7/C
# G:maj
# C:maj
# A:maj
# D:min
# A:maj
# D:min
# A:maj
# E:maj
# A:maj
# D:min
# A:maj
# D:min
# A:maj
# E:maj
# A:maj
# D:min
# A:7/E
# D:min/F
# A:7/C#
# D:min
# F#:dim/C
# G:min/Bb
# F#:dim
# G:min
# D:7/A
# G:min/Bb
# D:7/F#
# G:min
# F#:dim/C
# G:min/Bb
# F#:dim
# G:min
# E:dim/Bb
# F:7
# Bb:maj
# F:7/C
# Bb:maj/D
# F:7/A
# Bb:maj
# F:7
# Bb:min
# F:7
# Bb:min
# C:7
# F:min
# Db:maj
# F:min/C
# B:dim7
# G#:(bb3, b5, bb7)/Bb
# D:min/A
# A:maj
# D:maj
# A:7/C#
# D:maj
# A:7/E
# D:maj/F#
# G:maj
# D:7/A
# G:maj/B
# A:7/C#
# D:maj
# E:min/G
# D:maj/A
# A:7
# D:maj
# G:min
# C:7
# F:maj
# C:7/G
# F:maj/A
# G:min7/Bb
# F:maj/C
# F:7/Eb
# Bb:maj/D
# C:7/E
# F:maj
# G:min/Bb
# F:maj/C
# C:7
# F:maj
# C:7
# F:maj
# F:min/C
# F:min
# Eb:maj
# Eb:7/Bb
# Ab:maj
# F:7/Eb
# Bb:maj/D
# B:(bb3, b5)/Db
# C:maj
# G:7/B
# C:maj
# G:7/D
# C:maj
# G:7/B
# C:maj
# G:7/D
# C:maj
# G:7/D
# C:maj
# G:7/D
# C:maj
# C:7/Bb
# F:maj
# C:7/Bb
# F:maj
# G:min
# C:maj
# F:maj
# F:min
# G:dim/Bb
# C:maj/E
# F:min
# G:dim/Bb
# C:maj/E
# F:min
# G:dim/Bb
# C:7
# Db:maj
# B:dim7
# C:7/Bb
# F:maj
# C:7/G
# F:maj
# C:7/G
# F:maj/A
# C:7/G
# F:maj/A
# G:min/Bb
# C:7
# F:maj
# G:7/F
# F:maj/C
# C:7
# F:maj
# Bb:maj/D
# G:7/B
# F:maj/C
# C:maj
# F:maj
# Bb:maj/D
# G:7/B
# F:maj/C
# C:maj
# F:maj
# C:maj
# F:maj
# C:maj
# F:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op010No2-01_DB84.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op010No2-01_DB84.jams
# Converting Beethoven_Op014No2-01_AS35.csv...
# G:maj
# A:min7/G
# D:maj/F#
# D:7
# G:maj
# A:min7/C
# G:maj/D
# D:7
# G:maj
# D:7/A
# G:maj/B
# A:min/C
# A:7/C#
# D:maj
# B:min/D
# C#:hdim7/E
# F#:min
# D:maj/F#
# E:min/G
# E:7/G#
# A:maj
# E:7/D
# A:maj
# E:7
# A:maj
# E:7/D
# A:maj
# E:7
# A:maj
# E:7/D
# A:maj
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# E:7
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# D:maj/F#
# D:7/A
# G:maj
# G#:dim7
# D:maj/A
# A:7
# D:maj
# D:maj/A
# A:7
# D:maj
# A:7
# A:7/C#
# A:7
# D:maj/A
# B:min/F#
# E:min7/G
# A:7
# D:maj/A
# B:min/F#
# E:min7/G
# A:7
# D:maj/A
# B:min
# E:min/G
# A:7
# D:maj
# A:7/G
# D:maj
# A:7/G
# D:maj
# A:7/G
# D:maj
# A:7/G
# D:maj
# A:7/G
# A:7
# D:maj
# G:maj
# A:min7/G
# D:maj/F#
# D:7
# G:maj
# A:min7/C
# G:maj/D
# D:7
# G:maj
# D:7/A
# G:maj/B
# A:min/C
# A:7/C#
# D:maj
# B:min/D
# C#:hdim7/E
# F#:min
# D:maj/F#
# E:min/G
# E:7/G#
# A:maj
# E:7/D
# A:maj
# E:7
# A:maj
# E:7/D
# A:maj
# E:7
# A:maj
# E:7/D
# A:maj
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# E:7
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# D:maj/F#
# D:7/A
# G:maj
# G#:dim7
# D:maj/A
# A:7
# D:maj
# D:maj/A
# A:7
# D:maj
# A:7
# A:7/C#
# A:7
# D:maj/A
# B:min/F#
# E:min7/G
# A:7
# D:maj/A
# B:min/F#
# E:min7/G
# A:7
# D:maj/A
# B:min
# E:min/G
# A:7
# D:maj
# A:7/G
# D:maj
# A:7/G
# D:maj
# A:7/G
# D:maj
# A:7/G
# D:maj
# A:7/G
# A:7
# D:maj
# G:min
# C:min/G
# F#:dim7
# F:7
# Bb:maj
# F:7
# F#:dim7
# C:min/G
# Ab:maj
# D:7
# G:min
# C:7
# F:min
# F:7/C
# Bb:maj
# Bb:7
# Eb:maj
# F:min7/Eb
# Bb:maj/D
# Bb:7
# G:7/B
# C:min/G
# D:maj/F#
# D:7
# G:min
# C#:(bb3, b5, bb7)/Eb
# D:7
# G:min/D
# D:7
# G:min/D
# D:7
# G:min/D
# D:maj
# D:7
# G:maj
# A:min7/G
# D:maj/F#
# D:7
# G:maj
# A:min7/C
# G:maj/D
# D:7
# G:maj
# D:7/A
# G:maj/B
# G:7/B
# C:maj
# G:7/D
# C:maj/E
# D:min/F
# D:7/F#
# G:maj
# F#:hdim7/A
# B:min
# G:maj/B
# A:min/C
# A:7/C#
# D:maj
# A:7/G
# D:maj
# A:7
# D:maj
# A:7/G
# D:maj
# A:7
# D:maj
# A:7/G
# D:maj
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# A:7
# D:7
# G:maj/D
# D:7
# G:maj/D
# D:7
# G:maj
# G:maj/B
# G:7
# C:maj
# C#:dim7
# G:maj/D
# D:7
# G:maj
# G:maj/D
# D:7
# G:maj
# D:7
# D:7/F#
# D:7
# G:maj/D
# E:min/B
# A:min7/C
# D:7
# G:maj/D
# E:min/B
# A:min7/C
# D:7
# G:maj/D
# E:min
# C:maj/E
# C:maj
# A:7/C#
# G:maj/D
# D:7
# G:maj
# G:7
# C:maj
# G:maj7
# G:maj
# G:7
# C:maj
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op014No2-01_AS35.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op014No2-01_AS35.jams
# Converting Beethoven_Op054-01_AB96.csv...
# C:maj
# F:maj
# G:min7
# C:maj
# F:maj/A
# Bb:maj
# F:maj/C
# C:7
# F:maj
# C:maj
# F:maj
# G:min7
# C:maj
# F:maj/A
# Bb:maj
# F:maj/C
# C:7
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# G:min
# C:maj/E
# Bb:maj/D
# E:dim
# A:maj/C#
# G:min/Bb
# C:7
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# G:min
# C:maj/E
# Bb:maj/D
# E:dim
# A:maj/C#
# G:min/Bb
# C:7
# F:maj
# F:maj/A
# G:min
# F:maj/A
# G:min/Bb
# F:maj
# E:dim/G
# D:min
# C#:dim/E
# Bb:maj
# B:hdim7
# C:maj
# F:maj/A
# G:min
# A:min/C
# F:maj/A
# G:min/Bb
# F:maj/A
# A:7/G
# D:min/F
# G:7/F
# C:maj/E
# A:7/G
# D:min/F
# G:7/F
# C:maj/E
# C:maj/E
# G:7/F
# C:maj
# G:7/F
# C:maj
# G:7
# C:maj
# Ab:maj/C
# Bb:min
# Ab:maj/C
# Bb:min/Db
# Ab:maj
# G:dim/Bb
# F:min
# Eb:maj/G
# Db:maj
# D:hdim7
# Eb:maj
# Ab:maj/C
# Bb:min
# C:min/Eb
# Ab:maj/C
# Bb:min/Db
# Ab:maj/C
# C:7/Bb
# F:min/Ab
# Ab:7/Gb
# Db:maj/F
# F:7/Eb
# Bb:min/Db
# Eb:7/Db
# Ab:maj/C
# F:7/Eb
# Bb:min/Db
# Eb:7/Db
# Ab:maj/C
# Eb:7/Db
# Ab:maj/C
# Eb:7/G
# Ab:maj
# Eb:7/Db
# Ab:maj
# Eb:7/Db
# Ab:maj
# Eb:7
# Ab:maj
# F:min
# C:maj
# F:min
# Db:maj
# Ab:maj
# Db:maj
# Bb:min/Db
# B:(bb3, b5)/Db
# C:maj
# F:maj
# G:min7
# C:maj
# F:maj/A
# Bb:maj
# F:maj/C
# C:7
# F:maj
# C:maj
# F:maj
# G:min7
# C:maj
# F:maj/A
# Bb:maj
# F:maj/C
# C:7
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# G:min
# C:maj/E
# Bb:maj/D
# E:dim
# A:maj/C#
# G:min/Bb
# C:7
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# G:min
# C:maj/E
# Bb:maj/D
# E:dim
# A:maj/C#
# G:min/Bb
# C:7
# F:maj
# F:maj/A
# G:min
# F:maj/A
# G:min/Bb
# F:maj
# E:dim/G
# D:min
# C#:dim/E
# Bb:maj
# B:hdim7
# C:maj
# C:7
# C:7/Bb
# C:maj
# F:maj/A
# Bb:maj
# C:maj
# F:maj/C
# Bb:min
# F:maj/C
# C:7
# F:maj
# C:maj
# F:maj/A
# Bb:maj
# C:maj
# F:maj/C
# Bb:min
# F:maj/C
# C:7
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# G:min
# C:maj/E
# Bb:maj/D
# E:dim
# A:maj/C#
# G:min/Bb
# C:7
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# E:hdim7/G
# F:maj
# F:aug
# Bb:maj
# G:min
# C:maj/E
# Bb:maj/D
# E:dim
# A:maj/C#
# G:min/Bb
# C:7/Bb
# F:maj/A
# Bb:maj
# C:7/Bb
# F:maj/A
# D:7/F#
# G:min
# C:7/E
# F:maj
# F:maj/A
# G:min/Bb
# C:7
# F:maj
# C:7/Bb
# F:maj
# C:7
# F:maj
# C:7/Bb
# F:maj
# C:7
# F:maj
# E:dim7/G
# C:7/E
# F:maj
# C:maj
# F:maj
# C:maj
# F:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op054-01_AB96.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op054-01_AB96.jams
# Converting Beethoven_Op027No1-01_MB97.csv...
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# Eb:maj
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# B:dim7
# C:min
# G:maj
# Ab:maj7
# F:maj/A
# Bb:7
# Eb:maj
# Bb:7
# B:dim7
# C:min
# G:maj
# Ab:maj7
# F:maj/A
# Bb:7
# Eb:maj
# Eb:maj
# Bb:7/F
# Bb:7
# Eb:maj
# Eb:maj
# Bb:7/F
# Bb:7
# Eb:maj
# C:maj
# B:dim
# C:7/Bb
# F:min/Ab
# C:7/E
# F:min
# Bb:7
# Eb:maj/Bb
# Bb:7
# Eb:maj
# C:maj
# B:dim
# C:7/Bb
# F:min/Ab
# C:maj/E
# F:min
# Bb:7
# Eb:maj/Bb
# Bb:7
# Eb:maj
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# Eb:maj
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# B:dim7
# C:min
# G:maj
# Ab:maj7
# F:maj/A
# Bb:7
# Eb:maj
# Bb:7
# B:dim7
# C:min
# G:maj
# Ab:maj7
# F:maj/A
# Bb:7
# Eb:maj
# C:maj
# G:7/D
# G:maj
# G:7/B
# C:maj
# C:maj
# A:min7/C
# F:maj
# B:hdim7/D
# E:7/G#
# A:min
# D:7
# G:maj
# C:maj
# G:7/D
# G:maj
# G:7/B
# C:maj
# C:maj
# A:min7/C
# F:maj
# B:hdim7/D
# E:7/G#
# A:min
# D:7
# G:maj
# G:maj
# G:7
# C:maj/E
# A:min7/C
# F:maj
# B:dim
# C:maj
# D:min7
# G:7
# C:maj
# G:maj
# G:7
# C:min/Eb
# Ab:maj7/C
# F:min
# Bb:7/D
# Bb:7
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# Eb:maj
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7
# Bb:7/Ab
# Eb:maj/G
# Bb:7
# B:dim7
# C:min
# G:maj
# Ab:maj7
# F:maj/A
# Bb:7
# Eb:maj
# Bb:7/F
# Bb:7/D
# B:dim7/D
# Ab:maj/Eb
# G:maj/B
# C:min
# F:maj/A
# Bb:7
# Eb:maj
# G:dim
# Ab:maj/Eb
# D:dim
# Eb:maj
# D:dim
# Eb:maj
# D:dim
# Eb:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op027No1-01_MB97.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op027No1-01_MB97.jams
# Converting Beethoven_Op013-01_JJ90.csv...
# C:min
# G:maj/D
# F#:dim7
# G:maj
# B:dim7/Ab
# G:maj
# B:dim7
# C:min/Eb
# F#:dim7/Eb
# D:maj
# F#:dim7/C
# G:maj/B
# D:maj
# F#:dim7/C
# G:maj/B
# C:7/Bb
# F:min/Ab
# Eb:maj/Bb
# Bb:7
# Eb:maj
# F:min/Ab
# B:dim7/D
# F:min/C
# B:dim7
# Bb:7
# C#:dim7/Bb
# A:maj
# C#:dim7/G
# D:7/F#
# B:dim7/F
# B:dim/D
# B:dim7
# B:dim7/Ab
# G:7
# F:min/Ab
# G:7
# Ab:maj
# D:hdim7/F
# C:min/G
# G:7
# C:min
# F:min/Ab
# C:7
# F:min/Ab
# C:min
# G:7/D
# C:min/Eb
# D:dim/F
# C:min/G
# F#:dim7/A
# F#:dim7
# G:7
# C:min
# F:min/Ab
# C:7
# F:min/Ab
# C:min
# G:7/D
# C:min/Eb
# D:dim/F
# C:min/G
# F#:dim7/A
# F#:dim7
# G:maj
# C:min/G
# G:7/D
# C:min/G
# F#:dim7/A
# G:maj
# C:min/G
# G:7/D
# C:min/G
# F#:dim7/A
# G:maj
# F#:dim
# G:maj
# F#:dim
# G:maj
# Eb:7/G
# Ab:maj
# G:dim
# Ab:maj
# G:dim
# Ab:maj
# A:dim7
# Bb:maj
# A:dim
# Bb:maj
# A:dim
# Bb:maj
# A:dim
# Bb:maj
# A:dim
# Bb:maj
# A:dim
# Bb:maj
# A:dim
# Bb:maj
# Eb:min
# Bb:7
# Eb:min
# Ab:7
# Db:maj
# Ab:7
# Db:maj
# Db:7/Cb
# Bb:7
# Eb:min
# Eb:7/Db
# C:7
# F:min
# Bb:7
# B:dim7
# C:min
# F:min7/Ab
# Eb:maj/Bb
# Bb:maj
# Eb:maj
# Eb:7/Db
# Ab:maj/C
# C:7/Bb
# F:min/Ab
# C:min/G
# F:min
# F:7/Eb
# Bb:maj/D
# F:min/C
# Bb:min
# D:dim/Ab
# ...
# Bb:maj/D
# C:7/E
# F:maj
# G:min/Bb
# F:maj/C
# C:7
# F:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# G:maj
# C:maj
# G:7
# C:maj
# A:min
# D:7
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# D:7/F#
# G:maj
# D:7/F#
# G:maj
# G:7/F
# C:maj
# G:7/F
# C:maj
# D:min/F
# G:maj
# C:maj
# C:min/Eb
# D:dim/F
# G:maj/B
# C:min
# D:dim/F
# G:maj/B
# C:min
# D:dim/F
# G:7
# Ab:maj
# F#:dim7
# G:7/F
# C:maj
# G:7/D
# C:maj
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# D:min/F
# G:7
# C:maj
# F:maj
# D:7/F#
# C:maj/G
# G:maj
# C:maj
# F:maj
# D:7/F#
# C:maj/G
# G:maj
# C:maj
# F#:dim7/C
# G:maj
# C:maj
# F:maj
# C:7/E
# F:maj
# C:7/G
# F:maj/A
# C:7/E
# F:maj/C
# F:7/Eb
# Bb:maj/D
# C:7/E
# F:maj
# G:min/Bb
# F:maj/C
# C:7
# F:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# D#:(bb3, b5, bb7)/F
# E:maj
# G:maj
# C:maj
# G:7
# C:maj
# A:min
# D:7
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# D:7/A
# G:maj
# D:7/F#
# G:maj
# D:7/F#
# G:maj
# D:7/F#
# G:maj
# G:7/F
# C:maj
# G:7/F
# C:maj
# D:min/F
# G:maj
# C:maj
# C:min/Eb
# D:dim/F
# G:maj/B
# C:min
# D:dim/F
# G:maj/B
# C:min
# D:dim/F
# G:7
# Ab:maj
# F#:dim7
# G:7/F
# C:maj
# G:7/D
# C:maj
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# D:min/F
# G:7
# C:maj
# F:maj
# D:7/F#
# C:maj/G
# G:maj
# C:maj
# F:maj
# D:7/F#
# C:maj/G
# G:maj
# C:maj
# F#:dim7/C
# G:maj
# C:maj
# A:maj
# D:min
# A:maj
# D:min
# A:maj
# E:maj
# A:maj
# D:min
# A:maj
# D:min
# A:maj
# E:maj
# A:maj
# D:min
# A:7/E
# D:min/F
# A:7/C#
# D:min
# F#:dim/C
# G:min/Bb
# F#:dim
# G:min
# D:7/A
# G:min/Bb
# D:7/F#
# G:min
# F#:dim/C
# G:min/Bb
# F#:dim
# G:min
# E:dim/Bb
# F:7
# Bb:maj
# F:7/C
# Bb:maj/D
# F:7/A
# Bb:maj
# F:7
# Bb:min
# F:7
# Bb:min
# C:7
# F:min
# Db:maj
# F:min/C
# B:dim7
# G#:(bb3, b5, bb7)/Bb
# D:min/A
# A:maj
# D:maj
# A:7/C#
# D:maj
# A:7/E
# D:maj/F#
# G:maj
# D:7/A
# G:maj/B
# A:7/C#
# D:maj
# E:min/G
# D:maj/A
# A:7
# D:maj
# G:min
# C:7
# F:maj
# C:7/G
# F:maj/A
# G:min7/Bb
# F:maj/C
# F:7/Eb
# Bb:maj/D
# C:7/E
# F:maj
# G:min/Bb
# F:maj/C
# C:7
# F:maj
# C:7
# F:maj
# F:min/C
# F:min
# Eb:maj
# Eb:7/Bb
# Ab:maj
# F:7/Eb
# Bb:maj/D
# B:(bb3, b5)/Db
# C:maj
# G:7/B
# C:maj
# G:7/D
# C:maj
# G:7/B
# C:maj
# G:7/D
# C:maj
# G:7/D
# C:maj
# G:7/D
# C:maj
# C:7/Bb
# F:maj
# C:7/Bb
# F:maj
# G:min
# C:maj
# F:maj
# F:min
# G:dim/Bb
# C:maj/E
# F:min
# G:dim/Bb
# C:maj/E
# F:min
# G:dim/Bb
# C:7
# Db:maj
# B:dim7
# C:7/Bb
# F:maj
# C:7/G
# F:maj
# C:7/G
# F:maj/A
# C:7/G
# F:maj/A
# G:min/Bb
# C:7
# F:maj
# G:7/F
# F:maj/C
# C:7
# F:maj
# Bb:maj/D
# G:7/B
# F:maj/C
# C:maj
# F:maj
# Bb:maj/D
# G:7/B
# F:maj/C
# C:maj
# F:maj
# C:maj
# F:maj
# C:maj
# F:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op010No2-01_JJ90.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op010No2-01_JJ90.jams
# Converting Beethoven_Op028-01_DB84.csv...
# D:maj
# D:7
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:7
# G:maj
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:maj/F#
# E:min
# D:7/A
# G:maj/B
# D:7/A
# G:maj
# E:7/G#
# A:maj
# A:7
# D:maj
# A:7
# D:maj/F#
# E:min
# D:maj/A
# G:maj/B
# D:maj/A
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# D:maj/F#
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# B:min7/D
# A:maj/C#
# E:7/B
# A:maj
# F#:min7/A
# E:maj/G#
# B:7/F#
# E:maj
# B:min7/D
# A:maj/C#
# E:7/B
# A:maj
# F#:min7/A
# E:maj/G#
# B:7/F#
# E:maj
# B:7/F#
# E:maj
# B:7/F#
# E:maj
# C#:7
# F#:min
# C#:7
# F#:min
# F#:7
# B:min
# A:maj/C#
# E:7
# A:maj
# C#:maj
# F#:min
# C#:maj
# F#:min/A
# B:min/D
# B#:(bb3, b5)/D
# C#:maj
# B#:(bb3, b5)/D
# C#:maj
# B#:(bb3, b5)/D
# C#:maj
# B#:(bb3, b5)/D
# C#:maj
# A#:min7
# E#:dim7/B
# A#:min7
# E#:dim7/B
# A#:min7
# E#:dim7/B
# E:7/B
# A#:hdim7
# E:7/B
# A#:hdim7
# E:7/B
# A:maj
# E:7/B
# A:maj
# C#:7/G#
# F#:min
# C#:7/G#
# F#:min
# C#:7/G#
# F#:min
# A:7/E
# D:maj
# A:7/E
# D:maj
# A:7/E
# D:maj
# E:7/B
# A:maj/C#
# E:maj/G#
# A:maj
# D:maj/F#
# A:maj/C#
# D#:dim/F#
# A:maj/E
# E:7
# A:maj/C#
# B#:dim7
# A:maj/C#
# D:maj
# A:maj/C#
# E:7/B
# A:maj
# E:aug/G#
# A:maj
# E:7/B
# A:maj
# C#:7/G#
# F#:min
# C#:maj/E#
# F#:min
# C#:maj/E#
# F#:min
# F#:7/E
# B:min/D
# F#:maj/A#
# B:min/D
# B:7/A
# E:maj/G#
# B:maj/D#
# E:min
# E:7/D
# A:maj/C#
# B:7/F#
# A:maj/E
# E:7
# A:maj
# A:maj/C#
# E:7
# A:maj
# A:7/C#
# D:maj
# E:7
# A:maj
# A:maj/C#
# E:7
# A:maj
# A:7/C#
# D:maj
# E:7
# A:maj
# A:7/C#
# D:maj
# E:7
# A:maj
# E:7
# A:maj
# E:7
# A:maj
# A:7
# D:maj
# D:7
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:7
# G:maj
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:maj/F#
# E:min
# D:7/A
# G:maj/B
# D:7/A
# G:maj
# E:7/G#
# A:maj
# A:7
# D:maj
# A:7
# D:maj/F#
# E:min
# D:maj/A
# G:maj/B
# D:maj/A
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# D:maj/F#
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# B:min7/D
# A:maj/C#
# E:7/B
# A:maj
# F#:min7/A
# E:maj/G#
# B:7/F#
# E:maj
# B:min7/D
# A:maj/C#
# E:7/B
# A:maj
# F#:min7/A
# E:maj/G#
# B:7/F#
# E:maj
# B:7/F#
# E:maj
# B:7/F#
# E:maj
# C#:7
# F#:min
# C#:7
# F#:min
# F#:7
# B:min
# A:maj/C#
# E:7
# A:maj
# C#:maj
# F#:min
# C#:maj
# F#:min/A
# B:min/D
# B#:(bb3, b5)/D
# C#:maj
# B#:(bb3, b5)/D
# C#:maj
# B#:(bb3, b5)/D
# C#:maj
# B#:(bb3, b5)/D
# C#:maj
# A#:min7
# E#:dim7/B
# A#:min7
# E#:dim7/B
# A#:min7
# E#:dim7/B
# E:7/B
# A#:hdim7
# E:7/B
# A#:hdim7
# E:7/B
# A:maj
# E:7/B
# A:maj
# C#:7/G#
# F#:min
# C#:7/G#
# F#:min
# C#:7/G#
# F#:min
# A:7/E
# D:maj
# A:7/E
# D:maj
# A:7/E
# D:maj
# E:7/B
# A:maj/C#
# E:maj/G#
# A:maj
# D:maj/F#
# A:maj/C#
# D#:dim/F#
# A:maj/E
# E:7
# A:maj/C#
# B#:dim7
# A:maj/C#
# D:maj
# A:maj/C#
# E:7/B
# A:maj
# E:aug/G#
# A:maj
# E:7/B
# A:maj
# C#:7/G#
# F#:min
# C#:maj/E#
# F#:min
# C#:maj/E#
# F#:min
# F#:7/E
# B:min/D
# F#:maj/A#
# B:min/D
# B:7/A
# E:maj/G#
# B:maj/D#
# E:min
# E:7/D
# A:maj/C#
# B:7/F#
# A:maj/E
# E:7
# A:maj
# A:maj/C#
# E:7
# A:maj
# A:7/C#
# D:maj
# E:7
# A:maj
# A:maj/C#
# E:7
# A:maj
# A:7/C#
# D:maj
# E:7
# A:maj
# A:7/C#
# D:maj
# E:7
# A:maj
# E:7
# A:maj
# E:7
# A:maj
# A:7
# D:maj/F#
# D:7/F#
# G:maj
# G:7
# C:maj
# C:maj/E
# A:min7
# D:7/F#
# G:maj
# G:maj/B
# D:7
# G:maj
# D:7
# C:min
# C:min/Eb
# A:hdim7
# F#:dim7
# G:min
# D:7
# G:min
# A:maj/C#
# D:min
# A:7/C#
# D:min
# D:maj
# G:min
# D:7/F#
# G:min
# A:maj
# D:min
# A:7/C#
# D:min
# A:7/C#
# D:min
# A:7/C#
# D:min
# B:7/D#
# E:7/G#
# A:min
# E:7/G#
# A:min
# E:7/G#
# A:min
# D#:dim7/F#
# E:min
# B:7
# E:min
# A#:dim7/C#
# B:min
# F#:7
# B:min
# E#:(bb3, b5, bb7)/G
# F#:maj
# B:min/F#
# F#:7
# B:min/F#
# F#:maj
# B:min/F#
# F#:7
# B:min/F#
# F#:maj
# B:maj
# B:maj/D#
# F#:7
# B:maj
# B:min
# B:min/D
# F#:7
# B:min
# A:7
# D:maj
# D:7
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:7
# D:7/F#
# G:maj
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:maj/F#
# E:min7/G
# D:7/A
# G:maj/B
# D:7/A
# G:maj
# E:7/G#
# A:maj
# A:7
# D:maj
# A:7
# D:maj/F#
# E:min
# D:maj/A
# G:maj/B
# D:maj/A
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# D:maj/F#
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# D:maj/F#
# E:min7/G
# E:7/G#
# A:maj
# A:7
# D:maj
# B:min7/D
# A:maj/C#
# E:7/B
# A:maj
# E:min7/G
# D:maj/F#
# A:7/E
# D:maj
# B:min7/D
# A:maj/C#
# E:7/B
# A:maj
# E:min7/G
# D:maj/F#
# A:7/E
# D:maj
# E:7/B
# A:maj
# E:7/B
# A:maj
# E:7/B
# A:maj
# F#:7
# B:min
# F#:7
# B:min
# B:7
# E:min
# D:maj/F#
# A:7
# D:maj
# F#:maj
# B:min
# F#:maj
# B:min/D
# E:min/G
# E#:(bb3, b5)/G
# F#:maj
# E#:(bb3, b5)/G
# F#:maj
# E#:(bb3, b5)/G
# F#:maj
# E#:(bb3, b5)/G
# F#:maj
# D#:min7
# A#:dim7/E
# D#:min7
# A#:dim7/E
# D#:min7
# A#:dim7/E
# A:7/E
# D#:hdim7
# A:7/E
# D#:hdim7
# A:7/E
# D:maj
# A:7/E
# D:maj
# F#:7/C#
# B:min
# F#:7/C#
# B:min
# F#:7/C#
# B:min
# D:7/A
# G:maj
# D:7/A
# G:maj
# D:7/A
# G:maj
# A:7/E
# D:maj/F#
# A:maj/C#
# D:maj
# G:maj/B
# D:maj/F#
# G#:dim/B
# D:maj/A
# A:7
# D:maj/F#
# E#:dim7
# D:maj/F#
# G:maj
# D:maj/F#
# A:7/E
# D:maj
# A:aug/C#
# D:maj
# A:7/E
# D:maj
# F#:7/C#
# B:min
# F#:maj/A#
# B:min
# F#:maj/A#
# B:min
# B:7/A
# E:min/G
# B:maj/D#
# E:min/G
# E:7/D
# A:maj/C#
# E:maj/G#
# A:min
# A:7/G
# D:maj/F#
# G#:dim/B
# D:maj/A
# A:7
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:7/F#
# G:maj
# A:7
# D:maj
# D:maj/F#
# A:7
# D:maj
# D:7/F#
# G:maj
# A:7
# D:maj
# D:7/F#
# G:maj
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# D:7
# G:maj
# G:maj/B
# E:min7
# A:7/C#
# D:maj
# D:maj/F#
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# A:7
# D:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op028-01_DB84.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op028-01_DB84.jams
# Converting Beethoven_Op079-01_AS35.csv...
# G:maj
# C:maj
# A:min/C
# D:7/A
# G:maj
# D:maj/F#
# G:maj
# C:maj
# A:7/C#
# D:maj
# B:min
# E:7/G#
# A:maj
# E:7/G#
# A:7
# D:maj
# A:maj
# E:7/G#
# A:7
# D:maj
# A:maj
# B:min
# E:7/D
# A:7
# C#:dim7/Bb
# A:7
# A:7/G
# D:maj/F#
# D:maj
# A:7
# C#:dim7/Bb
# A:7
# A:7/G
# D:maj/F#
# D:maj
# G:maj
# E:min/G
# D:maj/A
# A:7
# D:maj
# A:7/E
# G:maj/B
# D:7/A
# G:maj
# C:maj
# A:min/C
# D:7/A
# G:maj
# D:maj/F#
# G:maj
# C:maj
# A:7/C#
# D:maj
# B:min
# E:7/G#
# A:maj
# E:7/G#
# A:7
# D:maj
# A:maj
# E:7/G#
# A:7
# D:maj
# A:maj
# B:min
# E:7/D
# A:7
# C#:dim7/Bb
# A:7
# A:7/G
# D:maj/F#
# D:maj
# A:7
# C#:dim7/Bb
# A:7
# A:7/G
# D:maj/F#
# D:maj
# G:maj
# E:min/G
# D:maj/A
# A:7
# D:maj
# A:7/E
# G:maj/B
# D:7/A
# E:maj/G#
# B:7/F#
# E:maj
# A:maj
# F#:min/A
# B:7/F#
# E:maj
# B:7
# E:min
# C:maj
# G:7
# C:maj
# G:maj/B
# C:maj
# F:maj
# D:7/F#
# G:maj
# F:maj
# D:7/F#
# G:maj
# F:min
# F:maj
# C:min
# G:7
# C:min
# Bb:maj
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7/D
# Eb:maj
# Ab:maj
# F:7/A
# Bb:maj
# Ab:maj
# F:7/A
# Bb:maj
# C:min/Eb
# F#:dim
# C:min/Eb
# D:maj/F#
# G:min
# C#:dim7
# D:maj
# A:7
# D:maj
# D:7
# G:maj
# C:maj
# D:7/A
# G:maj
# D:maj/F#
# G:maj
# D:7/A
# G:maj/B
# C:maj
# A:7
# D:maj
# A:7/C#
# D:7
# G:maj
# D:maj
# A:7/C#
# D:7
# G:maj
# D:maj
# E:min
# A:7/G
# D:7
# F#:dim7/Eb
# D:7
# D:7/C
# G:maj/B
# G:maj
# D:7
# F#:dim7/Eb
# D:7
# D:7/C
# G:maj/B
# G:maj
# C:maj
# A:min/C
# G:maj/D
# D:7
# G:maj
# D:7/A
# G:maj/B
# D:7/A
# E:maj/G#
# B:7/F#
# E:maj
# A:maj
# F#:min/A
# B:7/F#
# E:maj
# B:7
# E:min
# C:maj
# G:7
# C:maj
# G:maj/B
# C:maj
# F:maj
# D:7/F#
# G:maj
# F:maj
# D:7/F#
# G:maj
# F:min
# F:maj
# C:min
# G:7
# C:min
# Bb:maj
# Eb:maj
# Bb:7
# Eb:maj
# Bb:7/D
# Eb:maj
# Ab:maj
# F:7/A
# Bb:maj
# Ab:maj
# F:7/A
# Bb:maj
# C:min/Eb
# F#:dim
# C:min/Eb
# D:maj/F#
# G:min
# C#:dim7
# D:maj
# A:7
# D:maj
# D:7
# G:maj
# C:maj
# D:7/A
# G:maj
# D:maj/F#
# G:maj
# D:7/A
# G:maj/B
# C:maj
# A:7
# D:maj
# A:7/C#
# D:7
# G:maj
# D:maj
# A:7/C#
# D:7
# G:maj
# D:maj
# E:min
# A:7/G
# D:7
# F#:dim7/Eb
# D:7
# D:7/C
# G:maj/B
# G:maj
# D:7
# F#:dim7/Eb
# D:7
# D:7/C
# G:maj/B
# G:maj
# C:maj
# A:min/C
# G:maj/D
# D:7
# G:maj
# D:7/A
# G:maj/B
# D:7/A
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# C:maj/E
# E:min/G
# D:7
# G:maj
# C:maj/E
# E:min/G
# D:7
# G:maj
# D:7
# G:maj
# D:7
# G:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op079-01_AS35.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op079-01_AS35.jams
# Converting Beethoven_Op031No2-01_DB84.csv...
# A:maj/C#
# A:7/C#
# D:min
# A:maj/E
# D:min/F
# A:7/C#
# D:min
# A:maj/E
# D:min/F
# D:7/F#
# G:min
# D:min/A
# G:min/Bb
# G#:(bb3, b5)/Bb
# G#:dim7/D
# A:maj
# C:maj/E
# C:7/E
# F:maj
# D:7/F#
# G:min
# Eb:maj/G
# C#:dim7/G
# G#:dim7
# D:min/A
# A:7
# D:min
# A:7/E
# D:min/F
# E:maj/G#
# F:maj/A
# G#:dim/B
# A:min/C
# D#:dim7
# E:7
# A:min/E
# E:7
# A:min/C
# Bb:maj/D
# A:min/C
# Bb:maj/D
# A:min/C
# Bb:maj/D
# B:maj/D#
# A:min/E
# A:maj/E
# D:min/F
# A:maj/C#
# D:min
# Bb:maj/D
# A:min/E
# E:maj
# A:min
# Bb:maj
# A:maj
# Bb:maj
# A:maj
# Bb:maj
# G:7
# C:maj
# E:7
# A:min
# B:hdim7/D
# E:maj
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min/C
# E:7
# A:min/E
# E:maj
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min/C
# E:7
# A:min/E
# E:maj
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min
# E:maj
# A:min
# E:maj
# A:min
# A:maj/C#
# A:7/C#
# D:min
# A:maj/E
# D:min/F
# A:7/C#
# D:min
# A:maj/E
# D:min/F
# D:7/F#
# G:min
# D:min/A
# G:min/Bb
# G#:(bb3, b5)/Bb
# G#:dim7/D
# A:maj
# C:maj/E
# C:7/E
# F:maj
# D:7/F#
# G:min
# Eb:maj/G
# C#:dim7/G
# G#:dim7
# D:min/A
# A:7
# D:min
# A:7/E
# D:min/F
# E:maj/G#
# F:maj/A
# G#:dim/B
# A:min/C
# D#:dim7
# E:7
# A:min/E
# E:7
# A:min/C
# Bb:maj/D
# A:min/C
# Bb:maj/D
# A:min/C
# Bb:maj/D
# B:maj/D#
# A:min/E
# A:maj/E
# D:min/F
# A:maj/C#
# D:min
# Bb:maj/D
# A:min/E
# E:maj
# A:min
# Bb:maj
# A:maj
# Bb:maj
# A:maj
# Bb:maj
# G:7
# C:maj
# E:7
# A:min
# B:hdim7/D
# E:maj
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min/C
# E:7
# A:min/E
# E:maj
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min/C
# E:7
# A:min/E
# E:maj
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min
# E:maj
# A:min
# E:maj
# A:min
# D:maj/F#
# B#:dim7
# F#:maj/C#
# F#:min
# C#:7/G#
# F#:min/A
# B:min
# G:maj/B
# C:maj
# A:maj/C#
# D:min
# G#:dim/B
# G#:(bb3, b5)/Bb
# A:maj
# B:hdim7/A
# A:maj
# B:hdim7/A
# A:maj
# B:hdim7/A
# A:maj
# A:maj/C#
# B:hdim7
# A:maj/C#
# B:hdim7
# A:maj/C#
# B:hdim7
# A:maj
# B:hdim7/A
# A:maj
# B:hdim7/A
# A:maj
# B:hdim7/A
# A:maj
# D:min/A
# A:maj
# Bb:maj/D
# A:maj
# C#:dim7
# A:maj/C#
# A:7/C#
# D:min
# A:maj/E
# D:min/F
# A:7/C#
# D:min
# A:maj/E
# D:min/F
# D:7/F#
# G:min
# D:min/A
# G:min/Bb
# G#:(bb3, b5)/Bb
# G#:dim7/D
# A:maj
# C:maj/E
# E:dim7
# F:min
# C#:maj/E#
# F#:min
# D:maj/F#
# G:min
# C#:dim7/G
# G#:dim7
# A:7
# D:min/A
# A:7
# D:min/F
# Eb:maj/G
# D:min/F
# Eb:maj/G
# D:min/F
# Eb:maj/G
# E:maj/G#
# D:min/A
# D:maj/A
# G:min/Bb
# D:maj/F#
# G:min
# Eb:maj/G
# D:min/A
# A:maj
# D:min
# Eb:maj
# D:maj
# Eb:maj
# D:maj
# Eb:maj
# C:7
# F:maj
# A:7
# D:min
# E:hdim7/G
# A:maj
# D:min/A
# A:7
# D:min/A
# A:maj
# D:min/F
# A:7
# D:min/A
# A:maj
# D:min/A
# A:7
# D:min/A
# A:maj
# D:min/F
# A:7
# D:min/A
# A:maj
# D:min/A
# A:7
# D:min/A
# A:maj
# D:min
# A:maj
# D:min
# A:maj
# D:min
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op031No2-01_DB84.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op031No2-01_DB84.jams
# Converting Beethoven_Op053-01_AB96.csv...
# C:maj
# D:7/C
# G:maj/B
# Bb:maj
# C:7/Bb
# F:maj/A
# F:min/Ab
# G:7
# D:hdim7/Ab
# G:7
# D:hdim7/Ab
# G:7
# D:hdim7/Ab
# G:7
# C:min
# G:maj
# C:maj
# D:7/C
# G:maj/B
# D:min
# E:7/D
# A:min/C
# A#:(bb3, b5)/C
# B:7
# E:min/B
# B:7
# E:min/B
# B:7
# E:min/B
# B:7
# E:min/B
# B:maj
# E:min/B
# B:maj
# E:min/B
# B:maj
# E:min/B
# B:maj
# E:min/B
# B:maj
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# B:7/F#
# E:maj/G#
# F#:min7/A
# E:maj/B
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# E:maj/B
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# B:7/F#
# E:maj/G#
# F#:min7/A
# E:maj/B
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# E:maj/B
# B:7
# E:maj
# B:7
# E:maj/B
# B:7
# E:maj
# B:7/F#
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/D#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# E:7/G#
# A:maj
# F#:7/A#
# E:maj/B
# D#:dim7
# D#:hdim7
# B:7/D#
# E:maj
# E:7
# A:min/E
# E:7
# A:min
# F#:dim/A
# E:min/B
# B:7
# E:min
# E:7
# A:min/E
# E:7
# A:min
# F#:dim/A
# E:min/B
# B:7
# E:min
# E:min/G
# F#:dim/A
# E:min/B
# B:7
# C:maj
# C:maj/E
# D:min/F
# C:maj/G
# G:7
# C:maj
# D:7/C
# G:maj/B
# Bb:maj
# C:7/Bb
# F:maj/A
# F:min/Ab
# G:7
# D:hdim7/Ab
# G:7
# D:hdim7/Ab
# G:7
# D:hdim7/Ab
# G:7
# C:min
# G:maj
# C:maj
# D:7/C
# G:maj/B
# D:min
# E:7/D
# A:min/C
# A#:(bb3, b5)/C
# B:7
# E:min/B
# B:7
# E:min/B
# B:7
# E:min/B
# B:7
# E:min/B
# B:maj
# E:min/B
# B:maj
# E:min/B
# B:maj
# E:min/B
# B:maj
# E:min/B
# B:maj
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# B:7/F#
# E:maj/G#
# F#:min7/A
# E:maj/B
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# E:maj/B
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# B:7/F#
# E:maj/G#
# F#:min7/A
# E:maj/B
# B:7
# E:maj
# B:7
# C#:min
# G#:7
# A:maj
# E:maj/B
# B:7
# E:maj
# B:7
# E:maj/B
# B:7
# E:maj
# B:7/F#
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/D#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/F#
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# B:7/A
# E:maj/G#
# E:7/G#
# A:maj
# F#:7/A#
# E:maj/B
# D#:dim7
# D#:hdim7
# B:7/D#
# E:maj
# E:7
# A:min/E
# E:7
# A:min
# F#:dim/A
# E:min/B
# B:7
# E:min
# E:7
# A:min/E
# E:7
# A:min
# F#:dim/A
# E:min/B
# B:7
# E:min
# E:min/G
# F#:dim/A
# E:min/B
# B:7
# C:maj
# C:maj/E
# D:min/F
# C:maj/G
# G:7
# C:maj
# F:maj/A
# G:min/Bb
# F:maj/C
# C:7
# D:min
# F:maj/A
# G:min/Bb
# F:maj/C
# C:7
# F:maj
# G:7/F
# C:maj/E
# C:min/Eb
# D:maj
# D:7/F#
# G:min
# D:7/A
# G:min/Bb
# D:7/F#
# G:min
# D:7/A
# G:min/Bb
# G:7/B
# C:min
# G:7/D
# C:min/Eb
# G:7/B
# C:min
# G:7/D
# C:min/Eb
# C:7/E
# F:min
# Bb:min/F
# Gb:maj7/F
# Db:maj/F
# F:7/Eb
# Bb:min/Db
# Eb:7/Db
# Ab:maj/C
# Db:maj7/C
# Gb:maj/Bb
# C:7/Bb
# F:min/Ab
# C:7/G
# F:min
# C:maj/E
# G:7/D
# C:maj
# G:7/D
# C:maj/E
# B:dim7/F
# C:7/G
# F:maj
# C:7/G
# F:maj/A
# E:dim7/Bb
# F:7/C
# Bb:maj
# F:7/C
# Bb:maj/D
# A:dim7/Eb
# Bb:7/F
# Eb:min
# Eb:min/Bb
# F:7/C
# Bb:min/Db
# G:maj/D
# C:min/Eb
# Db:maj/F
# F#:dim7
# G:7
# C:min/G
# D:7/F#
# G:7
# C:min/G
# D:7/F#
# G:maj
# C:min
# G:maj
# F#:dim7/C
# G:maj
# F#:dim7/C
# G:maj
# F#:dim7/C
# G:maj
# G:7
# C:maj
# D:7/C
# G:maj/B
# Bb:maj
# C:7/Bb
# F:maj/A
# F:min/Ab
# G:7
# D:hdim7/Ab
# G:7
# D:hdim7/Ab
# G:7
# D:hdim7/Ab
# G:7
# C:min
# Ab:maj
# Db:maj
# Bb:maj
# Eb:maj
# F:min7
# B:dim7/Ab
# F#:dim7/A
# F#:dim7
# G:maj
# G:7
# C:maj
# D:7/C
# G:maj/B
# D:min
# E:7/D
# A:min/C
# F:maj
# D#:(bb3, b5, bb7)/F
# E:7
# A:min/E
# E:7
# A:min/E
# E:7
# A:min/E
# E:7
# A:min/E
# E:maj
# A:min/E
# E:maj
# A:min/E
# E:maj
# A:min/E
# E:maj
# A:min/E
# E:maj
# E:7
# A:maj
# E:maj
# F#:min
# C#:7
# D:maj
# E:7/B
# A:maj/C#
# B:min7/D
# A:maj/E
# E:7
# A:min
# E:min
# F:maj
# C:maj
# D:min
# C:maj/G
# G:7
# C:maj
# G#:dim7
# A:min
# E:7
# F:maj
# G:7/D
# C:maj/E
# D:min7/F
# C:maj/G
# G:7
# C:maj
# G#:dim7
# A:min
# E:7
# F:maj
# C:maj/G
# G:7
# C:maj
# G:7
# C:maj/G
# G:7
# C:maj
# G:7/D
# C:maj/E
# G:7/F
# C:maj/E
# G:7/B
# C:maj
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# G:7/D
# C:maj/E
# G:7/F
# C:maj/E
# G:7/F
# C:maj/E
# G:7/F
# C:maj/E
# G:7/F
# C:maj/E
# C:7/E
# F:maj
# D:7/F#
# C:maj/G
# B:dim7
# B:hdim7
# G:7/B
# C:maj
# C:7
# F:min/C
# C:7
# F:min
# Db:maj/F
# C:min/G
# G:7
# C:7
# F:maj/C
# C:7
# F:maj
# D:min/F
# C:maj/G
# G:7
# C:maj
# C:maj/E
# D:min/F
# C:maj/G
# G:7
# C:maj
# F:maj/A
# G:min/Bb
# F:maj/C
# C:7
# F:min
# F:min/Ab
# G:dim/Bb
# F:min/C
# C:7
# Db:maj
# Eb:7/Db
# Ab:maj/C
# F:7/C
# Bb:min/Db
# B:dim/D
# C:min/Eb
# D:dim/F
# E:dim/G
# F:min/Ab
# F#:dim7/A
# F#:(bb3, b5, bb7)/Ab
# G:maj
# G#:dim7/D
# G:maj/B
# A:7/C#
# D:min
# F:maj/A
# G:7/B
# C:maj
# A:min/C
# D:min
# B:dim/D
# C#:dim
# D:min
# E:min
# F:maj
# G:maj
# A:min
# B:dim
# C:maj/E
# F:maj
# C:maj/G
# G:7
# C:maj
# G#:dim7
# A:min
# E:maj
# F:maj
# G:7/D
# C:maj/E
# D:min7/F
# C:maj/G
# G:7
# C:maj
# G#:dim7
# A:min
# E:7
# F:maj
# C:maj/G
# G:7
# C:maj/G
# G:7
# C:maj/G
# G:7
# C:maj
# D:7/C
# G:maj/B
# C:7/Bb
# F:maj/A
# F:min/Ab
# G:7
# C:maj
# G:maj
# C:maj
# Converted /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op053-01_AB96.csv to /Users/theo/School/2/MIR/final-project/datasets/Beethoven_Piano_Sonata_Dataset_v2/2_Annotations/ann_audio_chord/Beethoven_Op053-01_AB96.jams
